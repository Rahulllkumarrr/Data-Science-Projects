# %% [markdown]
# # Imorting Libraries

# %%
import time
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score


from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Inserting Extra Features

# %% [markdown]
# # Brent Oil Futures Historical Data

# %%
brent_oil = pd.read_csv('Brent Oil Futures Historical Data.csv')

# %%
brent_oil.head()
# Out:
#            Date  Price   Open   High    Low     Vol. Change %
# 0  Dec 29, 2017  66.87  66.15  66.98  66.15  157.95K    0.22%
# 1  Dec 28, 2017  66.72  66.43  66.85  66.23   35.09K    0.42%
# 2  Dec 27, 2017  66.44  66.76  66.94  66.03  122.43K   -0.87%
# 3  Dec 26, 2017  67.02  65.20  67.10  65.00   74.25K    2.71%
# 4  Dec 22, 2017  65.25  64.63  65.28  64.38  110.42K    0.54%

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Dataset analysis

# %%
brent_oil[brent_oil.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Date, Price, Open, High, Low, Vol., Change %]
# Index: []

# %%
import numpy as np
np.sum(brent_oil.isnull().any(axis=1))
# Out:
# 0

# %%
brent_oil.isnull().any(axis=0)
# Out:
# Date        False
# Price       False
# Open        False
# High        False
# Low         False
# Vol.        False
# Change %    False
# dtype: bool

# %%
brent_oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1548 entries, 0 to 1547
# Data columns (total 7 columns):
# Date        1548 non-null object
# Price       1548 non-null float64
# Open        1548 non-null float64
# High        1548 non-null float64
# Low         1548 non-null float64
# Vol.        1548 non-null object
# Change %    1548 non-null object
# dtypes: float64(4), object(3)
# memory usage: 84.7+ KB

# %%
brent_oil.describe()
# Out:
#              Price         Open         High          Low
# count  1548.000000  1548.000000  1548.000000  1548.000000
# mean     78.919231    78.931654    79.784367    78.013714
# std      29.378784    29.342472    29.370363    29.297804
# min      27.880000    27.990000    28.750000    27.100000
# 25%      50.800000    50.882500    51.547500    50.060000
# 50%      66.230000    66.075000    66.905000    65.050000
# 75%     108.767500   108.682500   109.460000   107.792500
# max     126.220000   126.160000   128.400000   125.000000

# %%
brent_oil=brent_oil.rename(columns={'Change %':'Change_oil'})
brent_oil=brent_oil[['Date','Change_oil']]

# %%
brent_oil.head()
# Out:
#            Date Change_oil
# 0  Dec 29, 2017      0.22%
# 1  Dec 28, 2017      0.42%
# 2  Dec 27, 2017     -0.87%
# 3  Dec 26, 2017      2.71%
# 4  Dec 22, 2017      0.54%

# %% [markdown]
# # DAX Historical Data

# %%
DAX= pd.read_csv('DAX Historical Data.csv')

# %%
DAX.head()
# Out:
#            Date      Price       Open       High        Low    Vol. Change %
# 0  Dec 29, 2017  12,917.64  12,980.09  12,980.74  12,911.73  43.47M   -0.48%
# 1  Dec 28, 2017  12,979.94  13,065.46  13,069.40  12,965.28  44.49M   -0.69%
# 2  Dec 27, 2017  13,070.02  13,070.19  13,128.74  13,020.43  46.06M   -0.02%
# 3  Dec 22, 2017  13,072.79  13,076.76  13,108.56  13,059.87  54.51M   -0.28%
# 4  Dec 21, 2017  13,109.74  13,065.79  13,137.71  13,013.63  72.54M    0.31%

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Dataset analysis

# %%
DAX[DAX.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Date, Price, Open, High, Low, Vol., Change %]
# Index: []

# %%
import numpy as np
np.sum(DAX.isnull().any(axis=1))
# Out:
# 0

# %%
DAX.isnull().any(axis=0)
# Out:
# Date        False
# Price       False
# Open        False
# High        False
# Low         False
# Vol.        False
# Change %    False
# dtype: bool

# %%
DAX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 7 columns):
# Date        1520 non-null object
# Price       1520 non-null object
# Open        1520 non-null object
# High        1520 non-null object
# Low         1520 non-null object
# Vol.        1520 non-null object
# Change %    1520 non-null object
# dtypes: object(7)
# memory usage: 83.2+ KB

# %%
DAX.describe()
# Out:
#                 Date     Price       Open       High       Low    Vol.  \
# count           1520      1520       1520       1520      1520    1520
# unique          1520      1517       1519       1516      1518    1406
# top     Jun 11, 2012  9,339.17  11,881.49  11,881.81  9,805.55  82.31M
# freq               1         2          2          2         2       4
#
#        Change %
# count      1520
# unique      471
# top       0.19%
# freq         17

# %% [markdown]
# # Getting change feature

# %%
DAX=DAX.rename(columns={'Change %':'Change_DAX'})
DAX=DAX[['Date','Change_DAX']]

# %%
DAX.head()
# Out:
#            Date Change_DAX
# 0  Dec 29, 2017     -0.48%
# 1  Dec 28, 2017     -0.69%
# 2  Dec 27, 2017     -0.02%
# 3  Dec 22, 2017     -0.28%
# 4  Dec 21, 2017      0.31%

# %% [markdown]
# # Merging The data for change feature

# %%
aa=display('change_feature', 'DAX', "pd.merge(brent_oil, brent_oil, on='Date')")
# Out:
# 'change_feature'
# 'DAX'
# "pd.merge(brent_oil, brent_oil, on='Date')"

# %%
change_feature =pd.merge(brent_oil, DAX, on='Date')

# %%
change_feature.head()
# Out:
#            Date Change_oil Change_DAX
# 0  Dec 29, 2017      0.22%     -0.48%
# 1  Dec 28, 2017      0.42%     -0.69%
# 2  Dec 27, 2017     -0.87%     -0.02%
# 3  Dec 22, 2017      0.54%     -0.28%
# 4  Dec 21, 2017      0.53%      0.31%

# %% [markdown]
# # Gold Futures Historical Data

# %%
gold_features = pd.read_csv('Gold Futures Historical Data.csv')

# %%
gold_features.head()
# Out:
#            Date     Price      Open      High       Low   Vol. Change %
# 0  Jan 01, 2018  1,308.70  1,305.80  1,309.70  1,304.60      -   -2.87%
# 1  Dec 29, 2017  1,347.40  1,347.50  1,347.50  1,347.50  0.02K    4.12%
# 2  Dec 28, 2017  1,294.10  1,288.20  1,293.70  1,288.20  0.25K   -2.58%
# 3  Dec 27, 2017  1,328.40  1,328.30  1,328.30  1,328.30  0.00K    0.29%
# 4  Dec 26, 2017  1,324.60  1,320.50  1,324.10  1,320.50  0.01K    3.65%

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Dataset analysis

# %%
gold_features[gold_features.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Date, Price, Open, High, Low, Vol., Change %]
# Index: []

# %%
import numpy as np
np.sum(gold_features.isnull().any(axis=1))
# Out:
# 0

# %%
gold_features.isnull().any(axis=0)
# Out:
# Date        False
# Price       False
# Open        False
# High        False
# Low         False
# Vol.        False
# Change %    False
# dtype: bool

# %%
gold_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1564 entries, 0 to 1563
# Data columns (total 7 columns):
# Date        1564 non-null object
# Price       1564 non-null object
# Open        1564 non-null object
# High        1564 non-null object
# Low         1564 non-null object
# Vol.        1564 non-null object
# Change %    1564 non-null object
# dtypes: object(7)
# memory usage: 85.6+ KB

# %%
gold_features.describe()
# Out:
#                 Date     Price      Open      High       Low   Vol. Change %
# count           1564      1564      1564      1564      1564   1564     1564
# unique          1564      1280      1283      1283      1314    223      447
# top     Jun 11, 2012  1,273.70  1,252.70  1,254.50  1,218.60  0.01K    0.01%
# freq               1         5         5         4         5    127       16

# %% [markdown]
# # Getting change feature

# %%
gold_features=gold_features.rename(columns={'Change %':'Change_gold'})
gold_features=gold_features[['Date','Change_gold']]

# %%
gold_features.head()
# Out:
#            Date Change_gold
# 0  Jan 01, 2018      -2.87%
# 1  Dec 29, 2017       4.12%
# 2  Dec 28, 2017      -2.58%
# 3  Dec 27, 2017       0.29%
# 4  Dec 26, 2017       3.65%

# %% [markdown]
# # Merging The data for change feature

# %%
aa=display('change_feature', 'gold_features', "pd.merge(brent_oil, brent_oil, on='Date')")
# Out:
# 'change_feature'
# 'gold_features'
# "pd.merge(brent_oil, brent_oil, on='Date')"

# %%
change_feature =pd.merge(change_feature, gold_features, on='Date')

# %%
change_feature.head()
# Out:
#            Date Change_oil Change_DAX Change_gold
# 0  Dec 29, 2017      0.22%     -0.48%       4.12%
# 1  Dec 28, 2017      0.42%     -0.69%      -2.58%
# 2  Dec 27, 2017     -0.87%     -0.02%       0.29%
# 3  Dec 22, 2017      0.54%     -0.28%       0.65%
# 4  Dec 21, 2017      0.53%      0.31%       0.07%

# %% [markdown]
# # Nikkei 225 Historical Data

# %%
Nikkei= pd.read_csv('Nikkei 225 Historical Data.csv')

# %%
Nikkei.head()
# Out:
#            Date      Price       Open       High        Low     Vol. Change %
# 0  Dec 29, 2017  22,764.94  22,831.49  22,881.21  22,753.20  478.72M   -0.08%
# 1  Dec 28, 2017  22,783.98  22,912.05  22,954.45  22,736.43  519.04M   -0.56%
# 2  Dec 27, 2017  22,911.21  22,854.39  22,936.16  22,854.39  487.44M    0.08%
# 3  Dec 26, 2017  22,892.69  22,922.95  22,950.15  22,877.63  477.84M   -0.20%
# 4  Dec 25, 2017  22,939.18  22,909.41  22,948.83  22,870.19  444.48M    0.16%

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Dataset analysis

# %%
Nikkei[Nikkei.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Date, Price, Open, High, Low, Vol., Change %]
# Index: []

# %%
import numpy as np
np.sum(Nikkei.isnull().any(axis=1))
# Out:
# 0

# %%
Nikkei.isnull().any(axis=0)
# Out:
# Date        False
# Price       False
# Open        False
# High        False
# Low         False
# Vol.        False
# Change %    False
# dtype: bool

# %%
Nikkei.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 7 columns):
# Date        1502 non-null object
# Price       1502 non-null object
# Open        1502 non-null object
# High        1502 non-null object
# Low         1502 non-null object
# Vol.        1502 non-null object
# Change %    1502 non-null object
# dtypes: object(7)
# memory usage: 82.2+ KB

# %%
Nikkei.describe()
# Out:
#                 Date      Price       Open       High        Low  Vol.  \
# count           1502       1502       1502       1502       1502  1502
# unique          1502       1502       1500       1502       1500  1118
# top     Jun 11, 2012  14,326.46  19,953.06  14,839.79  17,869.74     -
# freq               1          1          2          1          2    29
#
#        Change %
# count      1502
# unique      491
# top      -0.39%
# freq         12

# %% [markdown]
# # Getting change feature

# %%
Nikkei=Nikkei.rename(columns={'Change %':'Change_Nikkei'})
Nikkei=Nikkei[['Date','Change_Nikkei']]

# %%
Nikkei.head()
# Out:
#            Date Change_Nikkei
# 0  Dec 29, 2017        -0.08%
# 1  Dec 28, 2017        -0.56%
# 2  Dec 27, 2017         0.08%
# 3  Dec 26, 2017        -0.20%
# 4  Dec 25, 2017         0.16%

# %% [markdown]
# # Merging The data for change feature

# %%
aa=display('change_feature', 'Nikkei', "pd.merge(change_feature, change_feature, on='Date')")
# Out:
# 'change_feature'
# 'Nikkei'
# "pd.merge(change_feature, change_feature, on='Date')"

# %%
change_feature =pd.merge(change_feature, Nikkei, on='Date')

# %%
change_feature.head()
# Out:
#            Date Change_oil Change_DAX Change_gold Change_Nikkei
# 0  Dec 29, 2017      0.22%     -0.48%       4.12%        -0.08%
# 1  Dec 28, 2017      0.42%     -0.69%      -2.58%        -0.56%
# 2  Dec 27, 2017     -0.87%     -0.02%       0.29%         0.08%
# 3  Dec 22, 2017      0.54%     -0.28%       0.65%         0.16%
# 4  Dec 21, 2017      0.53%      0.31%       0.07%        -0.11%

# %% [markdown]
# # S&P 500 Historical Data

# %%
SP= pd.read_csv('S&P 500 Historical Data.csv')

# %%
SP.head()
# Out:
#            Date     Price      Open      High       Low Vol. Change %
# 0  Dec 29, 2017  2,673.61  2,689.15  2,692.12  2,673.61    -   -0.52%
# 1  Dec 28, 2017  2,687.54  2,686.10  2,687.66  2,682.69    -    0.18%
# 2  Dec 27, 2017  2,682.62  2,682.10  2,685.64  2,678.91    -    0.08%
# 3  Dec 26, 2017  2,680.50  2,679.09  2,682.74  2,677.96    -   -0.11%
# 4  Dec 22, 2017  2,683.34  2,684.22  2,685.35  2,678.13    -   -0.05%

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Dataset analysis

# %%
SP[SP.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Date, Price, Open, High, Low, Vol., Change %]
# Index: []

# %%
import numpy as np
np.sum(SP.isnull().any(axis=1))
# Out:
# 0

# %%
SP.isnull().any(axis=0)
# Out:
# Date        False
# Price       False
# Open        False
# High        False
# Low         False
# Vol.        False
# Change %    False
# dtype: bool

# %%
SP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1509 entries, 0 to 1508
# Data columns (total 7 columns):
# Date        1509 non-null object
# Price       1509 non-null object
# Open        1509 non-null object
# High        1509 non-null object
# Low         1509 non-null object
# Vol.        1509 non-null object
# Change %    1509 non-null object
# dtypes: object(7)
# memory usage: 82.6+ KB

# %%
SP.describe()
# Out:
#                 Date     Price      Open      High       Low  Vol. Change %
# count           1509      1509      1509      1509      1509  1509     1509
# unique          1509      1500      1497      1494      1501     1      349
# top     Jun 11, 2012  2,268.90  1,413.09  2,578.29  2,041.88     -   -0.01%
# freq               1         2         2         2         3  1509       18

# %% [markdown]
# # Getting change feature

# %%
SP=SP.rename(columns={'Change %':'Change_SP'})
SP=SP[['Date','Change_SP']]

# %%
SP.head()
# Out:
#            Date Change_SP
# 0  Dec 29, 2017    -0.52%
# 1  Dec 28, 2017     0.18%
# 2  Dec 27, 2017     0.08%
# 3  Dec 26, 2017    -0.11%
# 4  Dec 22, 2017    -0.05%

# %% [markdown]
# # Merging The data for change feature

# %%
aa=display('change_feature', 'SP', "pd.merge(change_feature, change_feature, on='Date')")
# Out:
# 'change_feature'
# 'SP'
# "pd.merge(change_feature, change_feature, on='Date')"

# %%
change_feature =pd.merge(change_feature, SP, on='Date')

# %%
change_feature.head()
# Out:
#            Date Change_oil Change_DAX Change_gold Change_Nikkei Change_SP
# 0  Dec 29, 2017      0.22%     -0.48%       4.12%        -0.08%    -0.52%
# 1  Dec 28, 2017      0.42%     -0.69%      -2.58%        -0.56%     0.18%
# 2  Dec 27, 2017     -0.87%     -0.02%       0.29%         0.08%     0.08%
# 3  Dec 22, 2017      0.54%     -0.28%       0.65%         0.16%    -0.05%
# 4  Dec 21, 2017      0.53%      0.31%       0.07%        -0.11%     0.20%

# %% [markdown]
# # Shanghai Composite Historical Data

# %%
Shanghai= pd.read_csv('Shanghai Composite Historical Data.csv')

# %%
Shanghai.head()
# Out:
#            Date     Price      Open      High       Low    Vol. Change %
# 0  Dec 29, 2017  3,307.17  3,295.25  3,308.22  3,292.77  14.16B    0.33%
# 1  Dec 28, 2017  3,296.38  3,272.29  3,304.10  3,263.73  17.54B    0.63%
# 2  Dec 27, 2017  3,275.78  3,302.46  3,307.08  3,270.35  16.27B   -0.92%
# 3  Dec 26, 2017  3,306.12  3,277.84  3,307.30  3,274.33  14.24B    0.78%
# 4  Dec 25, 2017  3,280.46  3,296.21  3,312.30  3,270.44  14.69B   -0.50%

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Dataset analysis

# %%
Shanghai [Shanghai .isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Date, Price, Open, High, Low, Vol., Change %]
# Index: []

# %%
import numpy as np
np.sum(Shanghai .isnull().any(axis=1))
# Out:
# 0

# %%
Shanghai .isnull().any(axis=0)
# Out:
# Date        False
# Price       False
# Open        False
# High        False
# Low         False
# Vol.        False
# Change %    False
# dtype: bool

# %%
Shanghai .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 7 columns):
# Date        1459 non-null object
# Price       1459 non-null object
# Open        1459 non-null object
# High        1459 non-null object
# Low         1459 non-null object
# Vol.        1459 non-null object
# Change %    1459 non-null object
# dtypes: object(7)
# memory usage: 79.9+ KB

# %%
Shanghai .describe()
# Out:
#                 Date     Price      Open      High       Low   Vol. Change %
# count           1459      1459      1459      1459      1459   1459     1459
# unique          1459      1453      1448      1450      1452   1160      476
# top     Jun 11, 2012  2,073.10  2,023.15  3,219.52  2,132.63  7.16B    0.07%
# freq               1         2         2         2         2      6       15

# %% [markdown]
# # Getting change feature

# %%
Shanghai=Shanghai.rename(columns={'Change %':'Change_Shanghai'})
Shanghai=Shanghai[['Date','Change_Shanghai']]

# %%
Shanghai.head()
# Out:
#            Date Change_Shanghai
# 0  Dec 29, 2017           0.33%
# 1  Dec 28, 2017           0.63%
# 2  Dec 27, 2017          -0.92%
# 3  Dec 26, 2017           0.78%
# 4  Dec 25, 2017          -0.50%

# %% [markdown]
# # Merging The data for change feature

# %%
aa=display('change_feature', 'Shanghai', "pd.merge(change_feature, change_feature, on='Date')")
# Out:
# 'change_feature'
# 'Shanghai'
# "pd.merge(change_feature, change_feature, on='Date')"

# %%
change_feature =pd.merge(change_feature, Shanghai, on='Date')

# %%
change_feature.head()
# Out:
#            Date Change_oil Change_DAX Change_gold Change_Nikkei Change_SP  \
# 0  Dec 29, 2017      0.22%     -0.48%       4.12%        -0.08%    -0.52%
# 1  Dec 28, 2017      0.42%     -0.69%      -2.58%        -0.56%     0.18%
# 2  Dec 27, 2017     -0.87%     -0.02%       0.29%         0.08%     0.08%
# 3  Dec 22, 2017      0.54%     -0.28%       0.65%         0.16%    -0.05%
# 4  Dec 21, 2017      0.53%      0.31%       0.07%        -0.11%     0.20%
#
#   Change_Shanghai
# 0           0.33%
# 1           0.63%
# 2          -0.92%
# 3          -0.09%
# 4           0.38%

# %% [markdown]
# # USD_EUR Historical Data

# %%
USD_EUR= pd.read_csv('USD_EUR Historical Data.csv')

# %%
USD_EUR.head()
# Out:
#            Date   Price    Open    High     Low Change %
# 0  Jan 01, 2018  0.8327  0.8333  0.8337  0.8325   -0.10%
# 1  Dec 29, 2017  0.8335  0.8374  0.8378  0.8314   -0.47%
# 2  Dec 28, 2017  0.8374  0.8413  0.8413  0.8363   -0.44%
# 3  Dec 27, 2017  0.8411  0.8434  0.8437  0.8397   -0.26%
# 4  Dec 26, 2017  0.8433  0.8427  0.8441  0.8417    0.08%

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Dataset analysis

# %%
USD_EUR [USD_EUR .isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Date, Price, Open, High, Low, Change %]
# Index: []

# %%
import numpy as np
np.sum(USD_EUR .isnull().any(axis=1))
# Out:
# 0

# %%
USD_EUR .isnull().any(axis=0)
# Out:
# Date        False
# Price       False
# Open        False
# High        False
# Low         False
# Change %    False
# dtype: bool

# %%
USD_EUR .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1566 entries, 0 to 1565
# Data columns (total 6 columns):
# Date        1566 non-null object
# Price       1566 non-null float64
# Open        1566 non-null float64
# High        1566 non-null float64
# Low         1566 non-null float64
# Change %    1566 non-null object
# dtypes: float64(4), object(2)
# memory usage: 73.5+ KB

# %%
USD_EUR .describe()
# Out:
#              Price         Open         High          Low
# count  1566.000000  1566.000000  1566.000000  1566.000000
# mean      0.829482     0.829388     0.832929     0.826056
# std       0.073472     0.073471     0.074230     0.072684
# min       0.717700     0.717700     0.718900     0.714500
# 25%       0.760300     0.760200     0.763525     0.756925
# 50%       0.827750     0.826300     0.830150     0.824700
# 75%       0.896375     0.896300     0.900000     0.892100
# max       0.962700     0.962700     0.967100     0.960000

# %% [markdown]
# # Getting change feature

# %%
USD_EUR=USD_EUR.rename(columns={'Change %':'Change_USD_EUR'})
USD_EUR=USD_EUR[['Date','Change_USD_EUR']]

# %%
USD_EUR.head()
# Out:
#            Date Change_USD_EUR
# 0  Jan 01, 2018         -0.10%
# 1  Dec 29, 2017         -0.47%
# 2  Dec 28, 2017         -0.44%
# 3  Dec 27, 2017         -0.26%
# 4  Dec 26, 2017          0.08%

# %% [markdown]
# # Merging The data for change feature

# %%
aa=display('change_feature', 'USD_EUR', "pd.merge(change_feature, change_feature, on='Date')")
# Out:
# 'change_feature'
# 'USD_EUR'
# "pd.merge(change_feature, change_feature, on='Date')"

# %%
change_feature =pd.merge(change_feature, USD_EUR, on='Date')

# %%
change_feature.head()
# Out:
#            Date Change_oil Change_DAX Change_gold Change_Nikkei Change_SP  \
# 0  Dec 29, 2017      0.22%     -0.48%       4.12%        -0.08%    -0.52%
# 1  Dec 28, 2017      0.42%     -0.69%      -2.58%        -0.56%     0.18%
# 2  Dec 27, 2017     -0.87%     -0.02%       0.29%         0.08%     0.08%
# 3  Dec 22, 2017      0.54%     -0.28%       0.65%         0.16%    -0.05%
# 4  Dec 21, 2017      0.53%      0.31%       0.07%        -0.11%     0.20%
#
#   Change_Shanghai Change_USD_EUR
# 0           0.33%         -0.47%
# 1           0.63%         -0.44%
# 2          -0.92%         -0.26%
# 3          -0.09%          0.13%
# 4           0.38%         -0.02%

# %% [markdown]
# # USD_GBP Historical Data

# %%
USD_GBP= pd.read_csv('USD_GBP Historical Data.csv')

# %%
USD_GBP.head()
# Out:
#            Date   Price    Open    High     Low Change %
# 0  Jan 01, 2018  0.7406  0.7399  0.7411  0.7396    0.09%
# 1  Dec 29, 2017  0.7399  0.7438  0.7449  0.7383   -0.54%
# 2  Dec 28, 2017  0.7439  0.7463  0.7466  0.7430   -0.33%
# 3  Dec 27, 2017  0.7464  0.7478  0.7481  0.7446   -0.17%
# 4  Dec 26, 2017  0.7477  0.7480  0.7492  0.7468   -0.04%

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Dataset analysis

# %%
USD_GBP [USD_GBP .isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Date, Price, Open, High, Low, Change %]
# Index: []

# %%
import numpy as np
np.sum(USD_GBP
       .isnull().any(axis=1))
# Out:
# 0

# %%
USD_GBP .isnull().any(axis=0)
# Out:
# Date        False
# Price       False
# Open        False
# High        False
# Low         False
# Change %    False
# dtype: bool

# %%
USD_GBP .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1566 entries, 0 to 1565
# Data columns (total 6 columns):
# Date        1566 non-null object
# Price       1566 non-null float64
# Open        1566 non-null float64
# High        1566 non-null float64
# Low         1566 non-null float64
# Change %    1566 non-null object
# dtypes: float64(4), object(2)
# memory usage: 73.5+ KB

# %%
USD_GBP .describe()
# Out:
#              Price         Open         High          Low
# count  1566.000000  1566.000000  1566.000000  1566.000000
# mean      0.674902     0.674777     0.677634     0.672232
# std       0.066260     0.066275     0.067085     0.065594
# min       0.582600     0.582500     0.583500     0.581600
# 25%       0.626025     0.625950     0.628400     0.624025
# 50%       0.650000     0.649900     0.652350     0.647350
# 75%       0.740125     0.739800     0.743475     0.735775
# max       0.830000     0.829600     0.846100     0.827700

# %% [markdown]
# # Getting change feature

# %%
USD_GBP=USD_GBP.rename(columns={'Change %':'Change_USD_GBP'})
USD_GBP=USD_GBP[['Date','Change_USD_GBP']]

# %%
USD_GBP.head()
# Out:
#            Date Change_USD_GBP
# 0  Jan 01, 2018          0.09%
# 1  Dec 29, 2017         -0.54%
# 2  Dec 28, 2017         -0.33%
# 3  Dec 27, 2017         -0.17%
# 4  Dec 26, 2017         -0.04%

# %% [markdown]
# # Merging The data for change feature

# %%
aa=display('change_feature', 'USD_GBP', "pd.merge(change_feature, change_feature, on='Date')")
# Out:
# 'change_feature'
# 'USD_GBP'
# "pd.merge(change_feature, change_feature, on='Date')"

# %%
change_feature =pd.merge(change_feature, USD_GBP, on='Date')

# %%
change_feature.head()
# Out:
#            Date Change_oil Change_DAX Change_gold Change_Nikkei Change_SP  \
# 0  Dec 29, 2017      0.22%     -0.48%       4.12%        -0.08%    -0.52%
# 1  Dec 28, 2017      0.42%     -0.69%      -2.58%        -0.56%     0.18%
# 2  Dec 27, 2017     -0.87%     -0.02%       0.29%         0.08%     0.08%
# 3  Dec 22, 2017      0.54%     -0.28%       0.65%         0.16%    -0.05%
# 4  Dec 21, 2017      0.53%      0.31%       0.07%        -0.11%     0.20%
#
#   Change_Shanghai Change_USD_EUR Change_USD_GBP
# 0           0.33%         -0.47%         -0.54%
# 1           0.63%         -0.44%         -0.33%
# 2          -0.92%         -0.26%         -0.17%
# 3          -0.09%          0.13%          0.16%
# 4           0.38%         -0.02%         -0.08%

# %% [markdown]
# # USD_JPY Historical Data

# %%
USD_JPY= pd.read_csv('USD_JPY Historical Data.csv')

# %%
USD_JPY.head()
# Out:
#            Date   Price    Open    High     Low Change %
# 0  Jan 01, 2018  112.66  112.67  112.69  112.64   -0.03%
# 1  Dec 29, 2017  112.69  112.88  112.98  112.47   -0.18%
# 2  Dec 28, 2017  112.89  113.36  113.36  112.67   -0.41%
# 3  Dec 27, 2017  113.36  113.25  113.39  113.14    0.11%
# 4  Dec 26, 2017  113.23  113.28  113.36  113.12   -0.04%

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Dataset analysis

# %%
USD_JPY [USD_JPY .isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Date, Price, Open, High, Low, Change %]
# Index: []

# %%
import numpy as np
np.sum(USD_JPY .isnull().any(axis=1))
# Out:
# 0

# %%
USD_JPY.isnull().any(axis=0)
# Out:
# Date        False
# Price       False
# Open        False
# High        False
# Low         False
# Change %    False
# dtype: bool

# %%
USD_JPY .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1566 entries, 0 to 1565
# Data columns (total 6 columns):
# Date        1566 non-null object
# Price       1566 non-null float64
# Open        1566 non-null float64
# High        1566 non-null float64
# Low         1566 non-null float64
# Change %    1566 non-null object
# dtypes: float64(4), object(2)
# memory usage: 73.5+ KB

# %%
USD_JPY .describe()
# Out:
#              Price         Open         High          Low
# count  1566.000000  1566.000000  1566.000000  1566.000000
# mean    104.228889   104.191194   104.648091   103.726015
# std      13.553118    13.564863    13.623529    13.492504
# min      76.190000    76.180000    76.240000    76.020000
# 25%      98.237500    98.155000    98.705000    97.742500
# 50%     104.850000   104.835000   105.350000   104.300000
# 75%     113.897500   113.912500   114.355000   113.325000
# max     125.620000   125.580000   125.860000   124.520000

# %% [markdown]
# # Getting change feature

# %%
USD_JPY=USD_JPY.rename(columns={'Change %':'Change_USD_JPY'})
USD_JPY=USD_JPY[['Date','Change_USD_JPY']]

# %%
USD_JPY.head()
# Out:
#            Date Change_USD_JPY
# 0  Jan 01, 2018         -0.03%
# 1  Dec 29, 2017         -0.18%
# 2  Dec 28, 2017         -0.41%
# 3  Dec 27, 2017          0.11%
# 4  Dec 26, 2017         -0.04%

# %% [markdown]
# # Merging The data for change feature

# %%
aa=display('change_feature', 'USD_JPY', "pd.merge(change_feature, change_feature, on='Date')")
# Out:
# 'change_feature'
# 'USD_JPY'
# "pd.merge(change_feature, change_feature, on='Date')"

# %%
change_feature =pd.merge(change_feature, USD_JPY, on='Date')

# %%
change_feature
# Out:
#               Date Change_oil Change_DAX Change_gold Change_Nikkei Change_SP  \
# 0     Dec 29, 2017      0.22%     -0.48%       4.12%        -0.08%    -0.52%
# 1     Dec 28, 2017      0.42%     -0.69%      -2.58%        -0.56%     0.18%
# 2     Dec 27, 2017     -0.87%     -0.02%       0.29%         0.08%     0.08%
# 3     Dec 22, 2017      0.54%     -0.28%       0.65%         0.16%    -0.05%
# 4     Dec 21, 2017      0.53%      0.31%       0.07%        -0.11%     0.20%
# 5     Dec 20, 2017      1.19%     -1.11%       3.63%         0.10%    -0.08%
# 6     Dec 19, 2017      0.62%     -0.72%      -3.18%        -0.15%    -0.32%
# 7     Dec 18, 2017      0.28%      1.59%       0.63%         1.55%     0.54%
# 8     Dec 15, 2017     -0.13%      0.27%       0.02%        -0.62%     0.90%
# 9     Dec 14, 2017      1.39%     -0.44%       3.88%        -0.28%    -0.41%
# 10    Dec 13, 2017     -1.42%     -0.44%      -2.21%        -0.47%    -0.05%
# 11    Dec 12, 2017     -2.09%      0.46%      -0.78%        -0.32%     0.15%
# 12    Dec 11, 2017      2.03%     -0.23%      -0.10%         0.56%     0.32%
# 13    Dec 08, 2017      1.93%      0.83%      -0.38%         1.39%     0.55%
# 14    Dec 07, 2017      1.60%      0.36%       2.13%         1.45%     0.29%
# 15    Dec 06, 2017     -2.61%     -0.38%      -2.63%        -1.97%    -0.01%
# 16    Dec 05, 2017      0.66%     -0.08%       1.77%        -0.37%    -0.37%
# 17    Dec 04, 2017     -2.01%      1.53%      -3.07%        -0.49%    -0.11%
# 18    Dec 01, 2017      0.25%     -1.25%       3.25%         0.41%    -0.20%
# 19    Nov 30, 2017      0.73%     -0.29%      -0.69%         0.57%     0.82%
# 20    Nov 29, 2017     -0.79%      0.02%      -0.97%         0.49%    -0.04%
# 21    Nov 28, 2017     -0.36%      0.46%      -2.71%        -0.04%     0.98%
# 22    Nov 27, 2017     -0.03%     -0.46%       0.54%        -0.24%    -0.04%
# 23    Nov 24, 2017      0.49%      0.39%       2.48%         0.12%     0.21%
# 24    Nov 22, 2017      1.20%     -1.16%       4.06%         0.48%    -0.08%
# 25    Nov 21, 2017      0.56%      0.83%       0.51%         0.70%     0.65%
# 26    Nov 20, 2017     -0.80%      0.50%      -1.64%        -0.60%     0.13%
# 27    Nov 17, 2017      2.22%     -0.41%       1.44%         0.20%    -0.26%
# 28    Nov 16, 2017     -0.82%      0.55%       0.07%         1.47%     0.82%
# 29    Nov 15, 2017     -0.55%     -0.44%      -0.39%        -1.57%    -0.55%
# ...            ...        ...        ...         ...           ...       ...
# 1289  Feb 24, 2012      1.50%      0.81%      -0.55%         0.54%     0.17%
# 1290  Feb 23, 2012      0.59%     -0.50%       0.84%         0.44%     0.43%
# 1291  Feb 22, 2012      1.02%     -0.93%       0.73%         0.96%    -0.33%
# 1292  Feb 21, 2012      1.34%     -0.58%       1.89%        -0.23%     0.07%
# 1293  Feb 17, 2012     -0.44%      1.42%      -0.13%         1.58%     0.23%
# 1294  Feb 16, 2012      0.99%     -0.09%       0.03%        -0.24%     1.10%
# 1295  Feb 15, 2012      0.65%      0.44%       0.61%         2.30%    -0.54%
# 1296  Feb 14, 2012      0.20%     -0.15%      -0.41%         0.59%    -0.09%
# 1297  Feb 13, 2012      0.53%      0.68%      -0.02%         0.58%     0.68%
# 1298  Feb 10, 2012     -1.08%     -1.41%      -0.90%        -0.61%    -0.69%
# 1299  Feb 09, 2012      1.19%      0.59%       0.56%        -0.15%     0.15%
# 1300  Feb 08, 2012      0.83%     -0.08%      -0.98%         1.10%     0.22%
# 1301  Feb 07, 2012      0.26%     -0.16%       1.37%        -0.13%     0.20%
# 1302  Feb 06, 2012      1.18%     -0.03%      -0.87%         1.10%    -0.04%
# 1303  Feb 03, 2012      2.24%      1.67%      -1.08%        -0.51%     1.46%
# 1304  Feb 02, 2012      0.46%      0.59%       0.56%         0.76%     0.11%
# 1305  Feb 01, 2012      0.52%      2.44%       0.54%         0.08%     0.89%
# 1306  Jan 31, 2012      0.21%      0.22%       0.39%         0.11%    -0.05%
# 1307  Jan 30, 2012     -0.64%     -1.04%      -0.05%        -0.54%    -0.25%
# 1308  Jan 20, 2012     -1.52%     -0.18%       0.58%         1.47%     0.07%
# 1309  Jan 19, 2012      0.80%      0.97%      -0.33%         1.04%     0.49%
# 1310  Jan 18, 2012     -0.78%      0.34%       0.26%         0.99%     1.11%
# 1311  Jan 17, 2012      0.30%      1.82%       1.52%         1.05%     0.36%
# 1312  Jan 13, 2012     -0.74%     -0.58%      -1.03%         1.36%    -0.49%
# 1313  Jan 12, 2012     -0.87%      0.44%       0.49%        -0.74%     0.23%
# 1314  Jan 11, 2012     -0.92%     -0.17%       0.50%         0.30%     0.03%
# 1315  Jan 10, 2012      0.74%      2.42%       1.46%         0.38%     0.89%
# 1316  Jan 06, 2012      0.28%     -0.62%      -0.20%        -1.16%    -0.25%
# 1317  Jan 05, 2012     -0.84%     -0.25%       0.47%        -0.83%     0.29%
# 1318  Jan 04, 2012      1.40%     -0.89%       0.76%         1.24%     0.02%
#
#      Change_Shanghai Change_USD_EUR Change_USD_GBP Change_USD_JPY
# 0              0.33%         -0.47%         -0.54%         -0.18%
# 1              0.63%         -0.44%         -0.33%         -0.41%
# 2             -0.92%         -0.26%         -0.17%          0.11%
# 3             -0.09%          0.13%          0.16%         -0.05%
# 4              0.38%         -0.02%         -0.08%         -0.05%
# 5             -0.27%         -0.26%          0.08%          0.44%
# 6              0.88%         -0.49%         -0.01%          0.30%
# 7              0.05%         -0.24%         -0.47%         -0.03%
# 8             -0.80%          0.21%          0.82%          0.17%
# 9             -0.32%          0.40%         -0.07%         -0.14%
# 10             0.68%         -0.72%         -0.77%         -0.88%
# 11            -1.25%          0.24%          0.16%         -0.01%
# 12             0.98%         -0.04%          0.39%          0.07%
# 13             0.55%          0.07%          0.63%          0.35%
# 14            -0.67%          0.19%         -0.62%          0.69%
# 15            -0.29%          0.26%          0.38%         -0.26%
# 16            -0.18%          0.34%          0.27%          0.15%
# 17            -0.24%          0.21%         -0.04%          0.28%
# 18             0.01%          0.11%          0.39%         -0.37%
# 19            -0.62%         -0.47%         -0.87%          0.54%
# 20             0.13%         -0.06%         -0.52%          0.40%
# 21             0.34%          0.48%         -0.16%          0.35%
# 22            -0.94%          0.27%          0.15%         -0.41%
# 23             0.06%         -0.66%         -0.21%          0.30%
# 24             0.59%         -0.72%         -0.66%         -1.09%
# 25             0.53%         -0.06%         -0.04%         -0.16%
# 26             0.28%          0.54%         -0.16%          0.48%
# 27            -0.48%         -0.21%         -0.15%         -0.87%
# 28            -0.10%          0.18%         -0.17%          0.16%
# 29            -0.79%          0.06%         -0.05%         -0.50%
# ...              ...            ...            ...            ...
# 1289           1.25%         -0.62%         -0.88%          1.57%
# 1290           0.25%         -0.98%         -0.50%         -0.41%
# 1291           0.93%         -0.05%          0.74%          0.52%
# 1292           0.75%          0.03%          0.41%          0.30%
# 1293           0.01%         -0.13%         -0.22%          0.92%
# 1294          -0.42%         -0.51%         -0.66%          0.42%
# 1295           0.94%          0.38%         -0.06%          0.12%
# 1296          -0.30%          0.57%          0.52%          1.15%
# 1297          -0.01%         -0.09%         -0.16%         -0.12%
# 1298           0.10%          0.80%          0.47%         -0.06%
# 1299           0.09%         -0.21%         -0.02%          0.76%
# 1300           2.43%          0.04%          0.54%          0.39%
# 1301          -1.68%         -1.04%         -0.49%          0.27%
# 1302           0.03%          0.14%         -0.02%         -0.05%
# 1303           0.77%          0.01%         -0.09%          0.55%
# 1304           1.96%          0.09%          0.17%         -0.01%
# 1305          -1.07%         -0.61%         -0.49%         -0.10%
# 1306           0.33%          0.46%         -0.33%         -0.13%
# 1307          -1.47%          0.69%          0.19%         -0.42%
# 1308           1.00%          0.23%         -0.56%         -0.07%
# 1309           1.31%         -0.80%         -0.34%          0.37%
# 1310          -1.39%         -0.96%         -0.64%         -0.04%
# 1311           4.18%         -0.57%         -0.06%         -0.01%
# 1312          -1.34%          1.21%          0.11%          0.22%
# 1313          -0.05%         -0.94%         -0.11%         -0.10%
# 1314          -0.42%          0.55%          1.02%          0.02%
# 1315           2.69%         -0.08%         -0.17%         -0.02%
# 1316           0.70%          0.50%          0.39%         -0.27%
# 1317          -0.97%          1.26%          0.84%          0.58%
# 1318          -1.37%          0.82%          0.17%         -0.02%
#
# [1319 rows x 10 columns]

# %%
change_feature = change_feature.dropna(axis = 0, how ='any')

# %%
change_feature
# Out:
#               Date Change_oil Change_DAX Change_gold Change_Nikkei Change_SP  \
# 0     Dec 29, 2017      0.22%     -0.48%       4.12%        -0.08%    -0.52%
# 1     Dec 28, 2017      0.42%     -0.69%      -2.58%        -0.56%     0.18%
# 2     Dec 27, 2017     -0.87%     -0.02%       0.29%         0.08%     0.08%
# 3     Dec 22, 2017      0.54%     -0.28%       0.65%         0.16%    -0.05%
# 4     Dec 21, 2017      0.53%      0.31%       0.07%        -0.11%     0.20%
# 5     Dec 20, 2017      1.19%     -1.11%       3.63%         0.10%    -0.08%
# 6     Dec 19, 2017      0.62%     -0.72%      -3.18%        -0.15%    -0.32%
# 7     Dec 18, 2017      0.28%      1.59%       0.63%         1.55%     0.54%
# 8     Dec 15, 2017     -0.13%      0.27%       0.02%        -0.62%     0.90%
# 9     Dec 14, 2017      1.39%     -0.44%       3.88%        -0.28%    -0.41%
# 10    Dec 13, 2017     -1.42%     -0.44%      -2.21%        -0.47%    -0.05%
# 11    Dec 12, 2017     -2.09%      0.46%      -0.78%        -0.32%     0.15%
# 12    Dec 11, 2017      2.03%     -0.23%      -0.10%         0.56%     0.32%
# 13    Dec 08, 2017      1.93%      0.83%      -0.38%         1.39%     0.55%
# 14    Dec 07, 2017      1.60%      0.36%       2.13%         1.45%     0.29%
# 15    Dec 06, 2017     -2.61%     -0.38%      -2.63%        -1.97%    -0.01%
# 16    Dec 05, 2017      0.66%     -0.08%       1.77%        -0.37%    -0.37%
# 17    Dec 04, 2017     -2.01%      1.53%      -3.07%        -0.49%    -0.11%
# 18    Dec 01, 2017      0.25%     -1.25%       3.25%         0.41%    -0.20%
# 19    Nov 30, 2017      0.73%     -0.29%      -0.69%         0.57%     0.82%
# 20    Nov 29, 2017     -0.79%      0.02%      -0.97%         0.49%    -0.04%
# 21    Nov 28, 2017     -0.36%      0.46%      -2.71%        -0.04%     0.98%
# 22    Nov 27, 2017     -0.03%     -0.46%       0.54%        -0.24%    -0.04%
# 23    Nov 24, 2017      0.49%      0.39%       2.48%         0.12%     0.21%
# 24    Nov 22, 2017      1.20%     -1.16%       4.06%         0.48%    -0.08%
# 25    Nov 21, 2017      0.56%      0.83%       0.51%         0.70%     0.65%
# 26    Nov 20, 2017     -0.80%      0.50%      -1.64%        -0.60%     0.13%
# 27    Nov 17, 2017      2.22%     -0.41%       1.44%         0.20%    -0.26%
# 28    Nov 16, 2017     -0.82%      0.55%       0.07%         1.47%     0.82%
# 29    Nov 15, 2017     -0.55%     -0.44%      -0.39%        -1.57%    -0.55%
# ...            ...        ...        ...         ...           ...       ...
# 1289  Feb 24, 2012      1.50%      0.81%      -0.55%         0.54%     0.17%
# 1290  Feb 23, 2012      0.59%     -0.50%       0.84%         0.44%     0.43%
# 1291  Feb 22, 2012      1.02%     -0.93%       0.73%         0.96%    -0.33%
# 1292  Feb 21, 2012      1.34%     -0.58%       1.89%        -0.23%     0.07%
# 1293  Feb 17, 2012     -0.44%      1.42%      -0.13%         1.58%     0.23%
# 1294  Feb 16, 2012      0.99%     -0.09%       0.03%        -0.24%     1.10%
# 1295  Feb 15, 2012      0.65%      0.44%       0.61%         2.30%    -0.54%
# 1296  Feb 14, 2012      0.20%     -0.15%      -0.41%         0.59%    -0.09%
# 1297  Feb 13, 2012      0.53%      0.68%      -0.02%         0.58%     0.68%
# 1298  Feb 10, 2012     -1.08%     -1.41%      -0.90%        -0.61%    -0.69%
# 1299  Feb 09, 2012      1.19%      0.59%       0.56%        -0.15%     0.15%
# 1300  Feb 08, 2012      0.83%     -0.08%      -0.98%         1.10%     0.22%
# 1301  Feb 07, 2012      0.26%     -0.16%       1.37%        -0.13%     0.20%
# 1302  Feb 06, 2012      1.18%     -0.03%      -0.87%         1.10%    -0.04%
# 1303  Feb 03, 2012      2.24%      1.67%      -1.08%        -0.51%     1.46%
# 1304  Feb 02, 2012      0.46%      0.59%       0.56%         0.76%     0.11%
# 1305  Feb 01, 2012      0.52%      2.44%       0.54%         0.08%     0.89%
# 1306  Jan 31, 2012      0.21%      0.22%       0.39%         0.11%    -0.05%
# 1307  Jan 30, 2012     -0.64%     -1.04%      -0.05%        -0.54%    -0.25%
# 1308  Jan 20, 2012     -1.52%     -0.18%       0.58%         1.47%     0.07%
# 1309  Jan 19, 2012      0.80%      0.97%      -0.33%         1.04%     0.49%
# 1310  Jan 18, 2012     -0.78%      0.34%       0.26%         0.99%     1.11%
# 1311  Jan 17, 2012      0.30%      1.82%       1.52%         1.05%     0.36%
# 1312  Jan 13, 2012     -0.74%     -0.58%      -1.03%         1.36%    -0.49%
# 1313  Jan 12, 2012     -0.87%      0.44%       0.49%        -0.74%     0.23%
# 1314  Jan 11, 2012     -0.92%     -0.17%       0.50%         0.30%     0.03%
# 1315  Jan 10, 2012      0.74%      2.42%       1.46%         0.38%     0.89%
# 1316  Jan 06, 2012      0.28%     -0.62%      -0.20%        -1.16%    -0.25%
# 1317  Jan 05, 2012     -0.84%     -0.25%       0.47%        -0.83%     0.29%
# 1318  Jan 04, 2012      1.40%     -0.89%       0.76%         1.24%     0.02%
#
#      Change_Shanghai Change_USD_EUR Change_USD_GBP Change_USD_JPY
# 0              0.33%         -0.47%         -0.54%         -0.18%
# 1              0.63%         -0.44%         -0.33%         -0.41%
# 2             -0.92%         -0.26%         -0.17%          0.11%
# 3             -0.09%          0.13%          0.16%         -0.05%
# 4              0.38%         -0.02%         -0.08%         -0.05%
# 5             -0.27%         -0.26%          0.08%          0.44%
# 6              0.88%         -0.49%         -0.01%          0.30%
# 7              0.05%         -0.24%         -0.47%         -0.03%
# 8             -0.80%          0.21%          0.82%          0.17%
# 9             -0.32%          0.40%         -0.07%         -0.14%
# 10             0.68%         -0.72%         -0.77%         -0.88%
# 11            -1.25%          0.24%          0.16%         -0.01%
# 12             0.98%         -0.04%          0.39%          0.07%
# 13             0.55%          0.07%          0.63%          0.35%
# 14            -0.67%          0.19%         -0.62%          0.69%
# 15            -0.29%          0.26%          0.38%         -0.26%
# 16            -0.18%          0.34%          0.27%          0.15%
# 17            -0.24%          0.21%         -0.04%          0.28%
# 18             0.01%          0.11%          0.39%         -0.37%
# 19            -0.62%         -0.47%         -0.87%          0.54%
# 20             0.13%         -0.06%         -0.52%          0.40%
# 21             0.34%          0.48%         -0.16%          0.35%
# 22            -0.94%          0.27%          0.15%         -0.41%
# 23             0.06%         -0.66%         -0.21%          0.30%
# 24             0.59%         -0.72%         -0.66%         -1.09%
# 25             0.53%         -0.06%         -0.04%         -0.16%
# 26             0.28%          0.54%         -0.16%          0.48%
# 27            -0.48%         -0.21%         -0.15%         -0.87%
# 28            -0.10%          0.18%         -0.17%          0.16%
# 29            -0.79%          0.06%         -0.05%         -0.50%
# ...              ...            ...            ...            ...
# 1289           1.25%         -0.62%         -0.88%          1.57%
# 1290           0.25%         -0.98%         -0.50%         -0.41%
# 1291           0.93%         -0.05%          0.74%          0.52%
# 1292           0.75%          0.03%          0.41%          0.30%
# 1293           0.01%         -0.13%         -0.22%          0.92%
# 1294          -0.42%         -0.51%         -0.66%          0.42%
# 1295           0.94%          0.38%         -0.06%          0.12%
# 1296          -0.30%          0.57%          0.52%          1.15%
# 1297          -0.01%         -0.09%         -0.16%         -0.12%
# 1298           0.10%          0.80%          0.47%         -0.06%
# 1299           0.09%         -0.21%         -0.02%          0.76%
# 1300           2.43%          0.04%          0.54%          0.39%
# 1301          -1.68%         -1.04%         -0.49%          0.27%
# 1302           0.03%          0.14%         -0.02%         -0.05%
# 1303           0.77%          0.01%         -0.09%          0.55%
# 1304           1.96%          0.09%          0.17%         -0.01%
# 1305          -1.07%         -0.61%         -0.49%         -0.10%
# 1306           0.33%          0.46%         -0.33%         -0.13%
# 1307          -1.47%          0.69%          0.19%         -0.42%
# 1308           1.00%          0.23%         -0.56%         -0.07%
# 1309           1.31%         -0.80%         -0.34%          0.37%
# 1310          -1.39%         -0.96%         -0.64%         -0.04%
# 1311           4.18%         -0.57%         -0.06%         -0.01%
# 1312          -1.34%          1.21%          0.11%          0.22%
# 1313          -0.05%         -0.94%         -0.11%         -0.10%
# 1314          -0.42%          0.55%          1.02%          0.02%
# 1315           2.69%         -0.08%         -0.17%         -0.02%
# 1316           0.70%          0.50%          0.39%         -0.27%
# 1317          -0.97%          1.26%          0.84%          0.58%
# 1318          -1.37%          0.82%          0.17%         -0.02%
#
# [1319 rows x 10 columns]

# %%
change_feature.to_csv('change_feature.csv')

# %%
change_feature.head()
# Out:
#            Date Change_oil Change_DAX Change_gold Change_Nikkei Change_SP  \
# 0  Dec 29, 2017      0.22%     -0.48%       4.12%        -0.08%    -0.52%
# 1  Dec 28, 2017      0.42%     -0.69%      -2.58%        -0.56%     0.18%
# 2  Dec 27, 2017     -0.87%     -0.02%       0.29%         0.08%     0.08%
# 3  Dec 22, 2017      0.54%     -0.28%       0.65%         0.16%    -0.05%
# 4  Dec 21, 2017      0.53%      0.31%       0.07%        -0.11%     0.20%
#
#   Change_Shanghai Change_USD_EUR Change_USD_GBP Change_USD_JPY
# 0           0.33%         -0.47%         -0.54%         -0.18%
# 1           0.63%         -0.44%         -0.33%         -0.41%
# 2          -0.92%         -0.26%         -0.17%          0.11%
# 3          -0.09%          0.13%          0.16%         -0.05%
# 4           0.38%         -0.02%         -0.08%         -0.05%

# %%
import pandas as pd
change_feature  = pd.read_csv('change_feature.csv', index_col='Date', parse_dates=['Date'])
change_feature .head()
# Out:
#             Unnamed: 0 Change_oil Change_DAX Change_gold Change_Nikkei  \
# Date
# 2017-12-29           0      0.22%     -0.48%       4.12%        -0.08%
# 2017-12-28           1      0.42%     -0.69%      -2.58%        -0.56%
# 2017-12-27           2     -0.87%     -0.02%       0.29%         0.08%
# 2017-12-22           3      0.54%     -0.28%       0.65%         0.16%
# 2017-12-21           4      0.53%      0.31%       0.07%        -0.11%
#
#            Change_SP Change_Shanghai Change_USD_EUR Change_USD_GBP  \
# Date
# 2017-12-29    -0.52%           0.33%         -0.47%         -0.54%
# 2017-12-28     0.18%           0.63%         -0.44%         -0.33%
# 2017-12-27     0.08%          -0.92%         -0.26%         -0.17%
# 2017-12-22    -0.05%          -0.09%          0.13%          0.16%
# 2017-12-21     0.20%           0.38%         -0.02%         -0.08%
#
#            Change_USD_JPY
# Date
# 2017-12-29         -0.18%
# 2017-12-28         -0.41%
# 2017-12-27          0.11%
# 2017-12-22         -0.05%
# 2017-12-21         -0.05%

# %%
change_feature=change_feature.drop(columns=['Unnamed: 0'])
change_feature=change_feature.rename(columns={'Date':'date'})

# %%
aa=change_feature.iloc[::-1]
aa.to_csv('change_feature.csv')

# %%
change_feature  = pd.read_csv('change_feature.csv')
change_feature=change_feature.rename(columns={'Date':'date'})
change_feature.head()
# Out:
#          date Change_oil Change_DAX Change_gold Change_Nikkei Change_SP  \
# 0  2012-01-04      1.40%     -0.89%       0.76%         1.24%     0.02%
# 1  2012-01-05     -0.84%     -0.25%       0.47%        -0.83%     0.29%
# 2  2012-01-06      0.28%     -0.62%      -0.20%        -1.16%    -0.25%
# 3  2012-01-10      0.74%      2.42%       1.46%         0.38%     0.89%
# 4  2012-01-11     -0.92%     -0.17%       0.50%         0.30%     0.03%
#
#   Change_Shanghai Change_USD_EUR Change_USD_GBP Change_USD_JPY
# 0          -1.37%          0.82%          0.17%         -0.02%
# 1          -0.97%          1.26%          0.84%          0.58%
# 2           0.70%          0.50%          0.39%         -0.27%
# 3           2.69%         -0.08%         -0.17%         -0.02%
# 4          -0.42%          0.55%          1.02%          0.02%

# %% [markdown]
# # Cleaning % from all coloumns of change_feature

# %%
for letter in '%':
    change_feature['Change_oil']= change_feature['Change_oil'].str.replace(letter,'')

# %%
for letter in '%':
    change_feature['Change_DAX']= change_feature['Change_DAX'].str.replace(letter,'')

# %%
for letter in '%':
    change_feature['Change_gold']= change_feature['Change_gold'].str.replace(letter,'')

# %%
for letter in '%':
    change_feature['Change_Nikkei']= change_feature['Change_Nikkei'].str.replace(letter,'')

# %%
for letter in '%':
    change_feature['Change_SP']= change_feature['Change_SP'].str.replace(letter,'')

# %%
for letter in '%':
    change_feature['Change_Shanghai']= change_feature['Change_Shanghai'].str.replace(letter,'')

# %%
for letter in '%':
    change_feature['Change_USD_EUR']= change_feature['Change_USD_EUR'].str.replace(letter,'')

# %%
for letter in '%':
    change_feature['Change_USD_GBP']= change_feature['Change_USD_GBP'].str.replace(letter,'')

# %%
for letter in '%':
    change_feature['Change_USD_JPY']= change_feature['Change_USD_JPY'].str.replace(letter,'')

# %%
change_feature
# Out:
#             date Change_oil Change_DAX Change_gold Change_Nikkei Change_SP  \
# 0     2012-01-04       1.40      -0.89        0.76          1.24      0.02
# 1     2012-01-05      -0.84      -0.25        0.47         -0.83      0.29
# 2     2012-01-06       0.28      -0.62       -0.20         -1.16     -0.25
# 3     2012-01-10       0.74       2.42        1.46          0.38      0.89
# 4     2012-01-11      -0.92      -0.17        0.50          0.30      0.03
# 5     2012-01-12      -0.87       0.44        0.49         -0.74      0.23
# 6     2012-01-13      -0.74      -0.58       -1.03          1.36     -0.49
# 7     2012-01-17       0.30       1.82        1.52          1.05      0.36
# 8     2012-01-18      -0.78       0.34        0.26          0.99      1.11
# 9     2012-01-19       0.80       0.97       -0.33          1.04      0.49
# 10    2012-01-20      -1.52      -0.18        0.58          1.47      0.07
# 11    2012-01-30      -0.64      -1.04       -0.05         -0.54     -0.25
# 12    2012-01-31       0.21       0.22        0.39          0.11     -0.05
# 13    2012-02-01       0.52       2.44        0.54          0.08      0.89
# 14    2012-02-02       0.46       0.59        0.56          0.76      0.11
# 15    2012-02-03       2.24       1.67       -1.08         -0.51      1.46
# 16    2012-02-06       1.18      -0.03       -0.87          1.10     -0.04
# 17    2012-02-07       0.26      -0.16        1.37         -0.13      0.20
# 18    2012-02-08       0.83      -0.08       -0.98          1.10      0.22
# 19    2012-02-09       1.19       0.59        0.56         -0.15      0.15
# 20    2012-02-10      -1.08      -1.41       -0.90         -0.61     -0.69
# 21    2012-02-13       0.53       0.68       -0.02          0.58      0.68
# 22    2012-02-14       0.20      -0.15       -0.41          0.59     -0.09
# 23    2012-02-15       0.65       0.44        0.61          2.30     -0.54
# 24    2012-02-16       0.99      -0.09        0.03         -0.24      1.10
# 25    2012-02-17      -0.44       1.42       -0.13          1.58      0.23
# 26    2012-02-21       1.34      -0.58        1.89         -0.23      0.07
# 27    2012-02-22       1.02      -0.93        0.73          0.96     -0.33
# 28    2012-02-23       0.59      -0.50        0.84          0.44      0.43
# 29    2012-02-24       1.50       0.81       -0.55          0.54      0.17
# ...          ...        ...        ...         ...           ...       ...
# 1289  2017-11-15      -0.55      -0.44       -0.39         -1.57     -0.55
# 1290  2017-11-16      -0.82       0.55        0.07          1.47      0.82
# 1291  2017-11-17       2.22      -0.41        1.44          0.20     -0.26
# 1292  2017-11-20      -0.80       0.50       -1.64         -0.60      0.13
# 1293  2017-11-21       0.56       0.83        0.51          0.70      0.65
# 1294  2017-11-22       1.20      -1.16        4.06          0.48     -0.08
# 1295  2017-11-24       0.49       0.39        2.48          0.12      0.21
# 1296  2017-11-27      -0.03      -0.46        0.54         -0.24     -0.04
# 1297  2017-11-28      -0.36       0.46       -2.71         -0.04      0.98
# 1298  2017-11-29      -0.79       0.02       -0.97          0.49     -0.04
# 1299  2017-11-30       0.73      -0.29       -0.69          0.57      0.82
# 1300  2017-12-01       0.25      -1.25        3.25          0.41     -0.20
# 1301  2017-12-04      -2.01       1.53       -3.07         -0.49     -0.11
# 1302  2017-12-05       0.66      -0.08        1.77         -0.37     -0.37
# 1303  2017-12-06      -2.61      -0.38       -2.63         -1.97     -0.01
# 1304  2017-12-07       1.60       0.36        2.13          1.45      0.29
# 1305  2017-12-08       1.93       0.83       -0.38          1.39      0.55
# 1306  2017-12-11       2.03      -0.23       -0.10          0.56      0.32
# 1307  2017-12-12      -2.09       0.46       -0.78         -0.32      0.15
# 1308  2017-12-13      -1.42      -0.44       -2.21         -0.47     -0.05
# 1309  2017-12-14       1.39      -0.44        3.88         -0.28     -0.41
# 1310  2017-12-15      -0.13       0.27        0.02         -0.62      0.90
# 1311  2017-12-18       0.28       1.59        0.63          1.55      0.54
# 1312  2017-12-19       0.62      -0.72       -3.18         -0.15     -0.32
# 1313  2017-12-20       1.19      -1.11        3.63          0.10     -0.08
# 1314  2017-12-21       0.53       0.31        0.07         -0.11      0.20
# 1315  2017-12-22       0.54      -0.28        0.65          0.16     -0.05
# 1316  2017-12-27      -0.87      -0.02        0.29          0.08      0.08
# 1317  2017-12-28       0.42      -0.69       -2.58         -0.56      0.18
# 1318  2017-12-29       0.22      -0.48        4.12         -0.08     -0.52
#
#      Change_Shanghai Change_USD_EUR Change_USD_GBP Change_USD_JPY
# 0              -1.37           0.82           0.17          -0.02
# 1              -0.97           1.26           0.84           0.58
# 2               0.70           0.50           0.39          -0.27
# 3               2.69          -0.08          -0.17          -0.02
# 4              -0.42           0.55           1.02           0.02
# 5              -0.05          -0.94          -0.11          -0.10
# 6              -1.34           1.21           0.11           0.22
# 7               4.18          -0.57          -0.06          -0.01
# 8              -1.39          -0.96          -0.64          -0.04
# 9               1.31          -0.80          -0.34           0.37
# 10              1.00           0.23          -0.56          -0.07
# 11             -1.47           0.69           0.19          -0.42
# 12              0.33           0.46          -0.33          -0.13
# 13             -1.07          -0.61          -0.49          -0.10
# 14              1.96           0.09           0.17          -0.01
# 15              0.77           0.01          -0.09           0.55
# 16              0.03           0.14          -0.02          -0.05
# 17             -1.68          -1.04          -0.49           0.27
# 18              2.43           0.04           0.54           0.39
# 19              0.09          -0.21          -0.02           0.76
# 20              0.10           0.80           0.47          -0.06
# 21             -0.01          -0.09          -0.16          -0.12
# 22             -0.30           0.57           0.52           1.15
# 23              0.94           0.38          -0.06           0.12
# 24             -0.42          -0.51          -0.66           0.42
# 25              0.01          -0.13          -0.22           0.92
# 26              0.75           0.03           0.41           0.30
# 27              0.93          -0.05           0.74           0.52
# 28              0.25          -0.98          -0.50          -0.41
# 29              1.25          -0.62          -0.88           1.57
# ...              ...            ...            ...            ...
# 1289           -0.79           0.06          -0.05          -0.50
# 1290           -0.10           0.18          -0.17           0.16
# 1291           -0.48          -0.21          -0.15          -0.87
# 1292            0.28           0.54          -0.16           0.48
# 1293            0.53          -0.06          -0.04          -0.16
# 1294            0.59          -0.72          -0.66          -1.09
# 1295            0.06          -0.66          -0.21           0.30
# 1296           -0.94           0.27           0.15          -0.41
# 1297            0.34           0.48          -0.16           0.35
# 1298            0.13          -0.06          -0.52           0.40
# 1299           -0.62          -0.47          -0.87           0.54
# 1300            0.01           0.11           0.39          -0.37
# 1301           -0.24           0.21          -0.04           0.28
# 1302           -0.18           0.34           0.27           0.15
# 1303           -0.29           0.26           0.38          -0.26
# 1304           -0.67           0.19          -0.62           0.69
# 1305            0.55           0.07           0.63           0.35
# 1306            0.98          -0.04           0.39           0.07
# 1307           -1.25           0.24           0.16          -0.01
# 1308            0.68          -0.72          -0.77          -0.88
# 1309           -0.32           0.40          -0.07          -0.14
# 1310           -0.80           0.21           0.82           0.17
# 1311            0.05          -0.24          -0.47          -0.03
# 1312            0.88          -0.49          -0.01           0.30
# 1313           -0.27          -0.26           0.08           0.44
# 1314            0.38          -0.02          -0.08          -0.05
# 1315           -0.09           0.13           0.16          -0.05
# 1316           -0.92          -0.26          -0.17           0.11
# 1317            0.63          -0.44          -0.33          -0.41
# 1318            0.33          -0.47          -0.54          -0.18
#
# [1319 rows x 10 columns]

# %%
def get_data(symbol):

    # API KEY: 51N1JMO66W56AYA3
    ti = TechIndicators(key='51N1JMO66W56AYA3', output_format='pandas')
    sma, _ = ti.get_sma(symbol=symbol, interval='daily')
    wma, _ = ti.get_wma(symbol=symbol, interval='daily')
    ema, _ = ti.get_ema(symbol=symbol, interval='daily')
    macd, _ = ti.get_macd(symbol=symbol, interval='daily')
    stoch, _ = ti.get_stoch(symbol=symbol, interval='daily')
    #  Alpha Vantage Times out for more than 5 request 
    time.sleep(65)
    rsi, _ = ti.get_rsi(symbol=symbol, interval='daily')
    adx, _ = ti.get_adx(symbol=symbol, interval='daily')
    cci, _ = ti.get_cci(symbol=symbol, interval='daily')
    aroon, _ = ti.get_aroon(symbol=symbol, interval='daily')
    bbands, _ = ti.get_bbands(symbol=symbol, interval='daily')
    time.sleep(65)
    ad, _ = ti.get_ad(symbol=symbol, interval='daily')
    obv, _ = ti.get_obv(symbol=symbol, interval='daily')
    mom, _ = ti.get_mom(symbol=symbol, interval='daily')
    willr, _ = ti.get_willr(symbol=symbol, interval='daily')
    time.sleep(65)
    tech_ind = pd.concat([sma, ema, macd,  rsi, adx, cci, aroon, bbands, ad, obv, wma, mom, willr, stoch], axis=1)

    ts = TimeSeries(key='51N1JMO66W56AYA3', output_format='pandas')
    close2 = ts.get_daily(symbol=symbol, outputsize='full')
    close = ts.get_daily(symbol=symbol, outputsize='full')[0]['4. close']
    direction = (close > close.shift()).astype(int)
    target = direction.shift(-1).fillna(0).astype(int)
    target.name = 'target'

    data = pd.concat([tech_ind, close, target], axis=1)

    return data

# %%
def get_indicators(data, n):

    hh = data['2. high'].rolling(n).max()
    ll = data['3. low'].rolling(n).min()
    up, dw = data['4. close'].diff(), -data['4. close'].diff()
    up[up<0], dw[dw<0] = 0, 0
    macd = data['4. close'].ewm(12).mean() - data['4. close'].ewm(26).mean()
    macd_signal = macd.ewm(9).mean()
    tp = (data['2. high'] + data['3. low'] + data['4. close']) / 3
    tp_ma = tp.rolling(n).mean()
    indicators = pd.DataFrame(data=0, index=data.index,
                              columns=['sma', 'ema', 'momentum',
                                       'sto_k', 'sto_d', 'rsi',
                                       'macd', 'lw_r', 'a/d', 'cci'])
    indicators['sma'] = data['4. close'].rolling(10).mean()
    indicators['ema'] = data['4. close'].ewm(10).mean()
    indicators['momentum'] = data['4. close'] - data['4. close'].shift(n)
    indicators['sto_k'] = (data['4. close'] - ll) / (hh - ll) * 100
    indicators['sto_d'] = indicators['sto_k'].rolling(n).mean()
    indicators['rsi'] = 100 - 100 / (1 + up.rolling(14).mean() / dw.rolling(14).mean())
    indicators['macd'] = macd - macd_signal
    indicators['lw_r'] = (hh - data['4. close']) / (hh - ll) * 100
    indicators['a/d'] = (data['2. high'] - data['4. close'].shift()) / (data['2. high'] - data['3. low'])
    indicators['cci'] = (tp - tp_ma) / (0.015 * tp.rolling(n).apply(lambda x: np.std(x)))

    return indicators

# %%
def rebalance(unbalanced_data):

    # Separate majority and minority classes
    data_minority = unbalanced_data[unbalanced_data.target==0]
    data_majority = unbalanced_data[unbalanced_data.target==1]

    # Upsample minority class
    n_samples = len(data_majority)
    data_minority_upsampled = resample(data_minority, replace=True, n_samples=n_samples, random_state=5)

    # Combine majority class with upsampled minority class
    data_upsampled = pd.concat([data_majority, data_minority_upsampled])

    data_upsampled.sort_index(inplace=True)

    # Display new class counts
    data_upsampled.target.value_counts()

    return data_upsampled

# %%
def normalize(x):

    scaler = StandardScaler()
    x_norm = scaler.fit_transform(x.values)
    x_norm = pd.DataFrame(x_norm, index=x.index, columns=x.columns)

    return x_norm


def scores(models, X, y):

    for model in models:
        y_pred = model.predict(X)
        acc = accuracy_score(y, y_pred)
        f1 = f1_score(y, y_pred)
        auc = roc_auc_score(y, y_pred)
        print("Accuracy Score: {0:0.2f} %".format(acc * 100))
        print("F1 Score: {0:0.4f}".format(f1))
        print("Area Under ROC Curve Score: {0:0.4f}".format(auc))

# %%
symbolin = 'NDX'  # SPX, DJI, NDX
data = get_data(symbolin)
data.tail(10)
data.describe()
ax = data['4. close'].plot(figsize=(9, 5))
ax.set_ylabel("Price ($)")
ax.set_xlabel("Time")
plt.show()
data_train = data['2012-01-01':'2018-01-01']
data_train = rebalance(data_train)
y = data_train.target
X = data_train.drop('target', axis=1)
X = normalize(X)
data_val = data['2018-01-01':]
y_val = data_val.target
X_val = data_val.drop('target', axis=1)
X_val = normalize(X_val)

# %% [markdown]
# # API Data

# %%
X
# Out:
#                  SMA       EMA  MACD_Signal  MACD_Hist      MACD       RSI  \
# date
# 2012-01-03 -1.611602 -1.614177    -0.737994   0.504891 -0.515842 -0.262460
# 2012-01-04 -1.611459 -1.609446    -0.673373   0.667406 -0.397989 -0.185283
# 2012-01-05 -1.610127 -1.603442    -0.592500   0.841103 -0.260939 -0.002229
# 2012-01-06 -1.608462 -1.597376    -0.502048   0.943506 -0.139950  0.065193
# 2012-01-09 -1.605228 -1.592340    -0.413193   0.926442 -0.062469 -0.000649
# 2012-01-10 -1.602944 -1.586334    -0.322052   0.950853  0.031743  0.162543
# 2012-01-11 -1.599139 -1.580446    -0.232287   0.936150  0.110910  0.213824
# 2012-01-12 -1.593716 -1.574212    -0.143705   0.923519  0.189693  0.318167
# 2012-01-12 -1.593716 -1.574212    -0.143705   0.923519  0.189693  0.318167
# 2012-01-13 -1.587105 -1.569478    -0.066804   0.798662  0.218041  0.164829
# 2012-01-17 -1.579208 -1.563292     0.008517   0.781782  0.282875  0.392714
# 2012-01-18 -1.570266 -1.554701     0.094790   0.898853  0.405095  0.724212
# 2012-01-19 -1.559468 -1.545479     0.190196   0.996420  0.529031  0.874909
# 2012-01-19 -1.559468 -1.545479     0.190196   0.996420  0.529031  0.874909
# 2012-01-23 -1.543152 -1.530448     0.364401   0.858738  0.644292  0.789458
# 2012-01-23 -1.543152 -1.530448     0.364401   0.858738  0.644292  0.789458
# 2012-01-24 -1.535209 -1.524261     0.433066   0.710628  0.656730  0.733779
# 2012-01-25 -1.526742 -1.515761     0.503848   0.733240  0.731180  1.066072
# 2012-01-25 -1.526742 -1.515761     0.503848   0.733240  0.731180  1.066072
# 2012-01-25 -1.526742 -1.515761     0.503848   0.733240  0.731180  1.066072
# 2012-01-26 -1.519036 -1.509068     0.563946   0.619066  0.747501  0.856338
# 2012-01-27 -1.509760 -1.502378     0.615198   0.524510  0.762404  0.930787
# 2012-01-30 -1.501198 -1.496053     0.657003   0.423546  0.766185  0.963454
# 2012-01-31 -1.492161 -1.490058     0.689389   0.322846  0.761204  0.997258
# 2012-02-01 -1.484264 -1.482821     0.721697   0.322030  0.791273  1.218703
# 2012-02-02 -1.476368 -1.475547     0.753426   0.315859  0.818914  1.304419
# 2012-02-03 -1.467806 -1.465974     0.797327   0.445921  0.905886  1.633542
# 2012-02-06 -1.459625 -1.457403     0.842827   0.463021  0.954646  1.609978
# 2012-02-07 -1.451015 -1.449286     0.885732   0.435326  0.985222  1.649704
# 2012-02-08 -1.442500 -1.440672     0.928702   0.435976  1.025822  1.787906
# ...              ...       ...          ...        ...       ...       ...
# 2017-11-17  2.158617  2.166480     1.669623  -0.376719  1.436188  0.796053
# 2017-11-20  2.170081  2.171952     1.623200  -0.519500  1.342374  0.717285
# 2017-11-21  2.184304  2.183251     1.602439  -0.245182  1.419318  1.211014
# 2017-11-22  2.200048  2.194109     1.597489  -0.076242  1.474066  1.256131
# 2017-11-24  2.217696  2.206018     1.609732   0.107559  1.550193  1.403801
# 2017-11-24  2.217696  2.206018     1.609732   0.107559  1.550193  1.403801
# 2017-11-27  2.226876  2.216521     1.625483   0.145085  1.578185  1.360352
# 2017-11-28  2.236152  2.227565     1.646435   0.200614  1.617394  1.473245
# 2017-11-28  2.236152  2.227565     1.646435   0.200614  1.617394  1.473245
# 2017-11-29  2.239101  2.227401     1.605704  -0.458634  1.347340  0.043806
# 2017-11-30  2.244666  2.232241     1.552235  -0.594824  1.249217  0.459783
# 2017-12-01  2.249518  2.234080     1.473984  -0.859689  1.082573  0.159913
# 2017-12-04  2.247996  2.229034     1.340778  -1.447098  0.750892 -0.548774
# 2017-12-05  2.245665  2.224560     1.176192  -1.782493  0.478336 -0.540356
# 2017-12-06  2.244333  2.223050     1.011178  -1.787084  0.321685 -0.303733
# 2017-12-07  2.242906  2.223770     0.862908  -1.608094  0.245318 -0.115387
# 2017-12-08  2.244476  2.227051     0.744754  -1.286190  0.247490  0.114133
# 2017-12-11  2.248519  2.234463     0.674272  -0.776667  0.360415  0.473481
# 2017-12-12  2.251754  2.240262     0.629199  -0.505061  0.413567  0.364709
# 2017-12-13  2.256558  2.246506     0.605363  -0.278073  0.470981  0.446415
# 2017-12-14  2.262837  2.251702     0.590702  -0.179997  0.491693  0.388019
# 2017-12-15  2.268878  2.263294     0.619666   0.286251  0.682833  0.929218
# 2017-12-18  2.278296  2.278045     0.696284   0.795651  0.933922  1.215510
# 2017-12-19  2.286478  2.288489     0.779016   0.860985  1.034621  0.840408
# 2017-12-20  2.290902  2.297122     0.853365   0.771389  1.072972  0.736486
# 2017-12-26  2.298988  2.314358     0.969488   0.081085  0.939363  0.255053
# 2017-12-27  2.299559  2.317172     0.954762  -0.180708  0.833482  0.271889
# 2017-12-28  2.305743  2.320263     0.925039  -0.340984  0.749204  0.324265
# 2017-12-28  2.305743  2.320263     0.925039  -0.340984  0.749204  0.324265
# 2017-12-29  2.307170  2.318978     0.860401  -0.714203  0.557252 -0.224855
#
#                  ADX       CCI  Aroon Down  Aroon Up    ...     \
# date                                                    ...
# 2012-01-03 -1.597748  0.760145    0.402856 -1.914956    ...
# 2012-01-04 -1.608967  0.793523    0.260194 -2.065535    ...
# 2012-01-05 -1.588809  1.138424    0.117532  0.946039    ...
# 2012-01-06 -1.549648  1.315156   -0.025130  0.946039    ...
# 2012-01-09 -1.512439  1.030520   -0.167792  0.946039    ...
# 2012-01-10 -1.446462  1.153570   -0.310454  0.946039    ...
# 2012-01-11 -1.390863  0.886389   -0.453116  0.795460    ...
# 2012-01-12 -1.325713  0.778620   -0.595777  0.946039    ...
# 2012-01-12 -1.325713  0.778620   -0.595777  0.946039    ...
# 2012-01-13 -1.281491  0.531302   -0.738439  0.795460    ...
# 2012-01-17 -1.186645  0.784976   -0.881101  0.946039    ...
# 2012-01-18 -1.061662  0.930042   -1.023763  0.946039    ...
# 2012-01-19 -0.913427  1.098352   -1.166425  0.946039    ...
# 2012-01-19 -0.913427  1.098352   -1.166425  0.946039    ...
# 2012-01-23 -0.640466  0.820616   -1.166425  0.946039    ...
# 2012-01-23 -0.640466  0.820616   -1.166425  0.946039    ...
# 2012-01-24 -0.504777  0.648489   -1.166425  0.795460    ...
# 2012-01-25 -0.331779  0.877104   -0.881101  0.946039    ...
# 2012-01-25 -0.331779  0.877104   -0.881101  0.946039    ...
# 2012-01-25 -0.331779  0.877104   -0.881101  0.946039    ...
# 2012-01-26 -0.156800  0.746273   -1.023763  0.946039    ...
# 2012-01-27  0.009426  0.624883   -1.166425  0.795460    ...
# 2012-01-30  0.116318  0.491768   -1.166425  0.644881    ...
# 2012-01-31  0.237851  0.561798   -1.166425  0.946039    ...
# 2012-02-01  0.375451  0.719516   -1.023763  0.946039    ...
# 2012-02-02  0.516272  0.766772   -1.166425  0.946039    ...
# 2012-02-03  0.687930  1.077500   -1.166425  0.946039    ...
# 2012-02-06  0.847541  0.951724   -1.023763  0.795460    ...
# 2012-02-07  1.012441  0.902956   -1.166425  0.946039    ...
# 2012-02-08  1.179579  0.928728   -0.738439  0.946039    ...
# ...              ...       ...         ...       ...    ...
# 2017-11-17  0.076643  0.359339   -0.738439  0.795460    ...
# 2017-11-20  0.089360  0.238806   -0.881101  0.644881    ...
# 2017-11-21  0.157703  0.698053   -1.023763  0.946039    ...
# 2017-11-22  0.233090  0.906679   -1.166425  0.946039    ...
# 2017-11-24  0.323573  1.213551   -1.166425  0.946039    ...
# 2017-11-24  0.323573  1.213551   -1.166425  0.946039    ...
# 2017-11-27  0.417991  1.152659   -1.166425  0.946039    ...
# 2017-11-28  0.494232  1.045495   -0.738439  0.946039    ...
# 2017-11-28  0.494232  1.045495   -0.738439  0.946039    ...
# 2017-11-29  0.394340 -0.148435   -0.881101  0.795460    ...
# 2017-11-30  0.299437  0.090690   -1.023763  0.644881    ...
# 2017-12-01  0.201512 -0.622846   -1.166425  0.494303    ...
# 2017-12-04  0.087678 -0.936840   -0.025130  0.343724    ...
# 2017-12-05  0.004707 -1.274507   -0.167792  0.193145    ...
# 2017-12-06 -0.071691 -1.240347   -0.310454  0.042567    ...
# 2017-12-07 -0.184614 -0.597146   -0.453116 -0.108012    ...
# 2017-12-08 -0.257063  0.021799   -0.595777 -0.258591    ...
# 2017-12-11 -0.306660  0.372506   -0.738439 -0.409169    ...
# 2017-12-12 -0.341716  0.405220   -0.881101 -0.559748    ...
# 2017-12-13 -0.359222  0.514636   -1.023763 -0.710327    ...
# 2017-12-14 -0.367248  0.449831   -1.166425 -0.860905    ...
# 2017-12-15 -0.320260  1.014831    0.688179  0.946039    ...
# 2017-12-18 -0.223162  1.585379    0.545518  0.946039    ...
# 2017-12-19 -0.183972  1.055096    0.402856  0.795460    ...
# 2017-12-20 -0.170728  0.772393    0.260194  0.644881    ...
# 2017-12-26 -0.259871  0.024616   -0.167792  0.193145    ...
# 2017-12-27 -0.323311  0.108567   -0.310454  0.042567    ...
# 2017-12-28 -0.379509  0.114145   -0.453116 -0.108012    ...
# 2017-12-28 -0.379509  0.114145   -0.453116 -0.108012    ...
# 2017-12-29 -0.486928 -0.222502   -0.595777 -0.258591    ...
#
#             Real Lower Band  Real Middle Band  Chaikin A/D       OBV  \
# date
# 2012-01-03        -1.595463         -1.611602    -1.677234 -1.498378
# 2012-01-04        -1.595754         -1.611459    -1.665066 -1.472565
# 2012-01-05        -1.598776         -1.610127    -1.649598 -1.444190
# 2012-01-06        -1.602360         -1.608462    -1.644221 -1.418183
# 2012-01-09        -1.604598         -1.605228    -1.646642 -1.445503
# 2012-01-10        -1.608419         -1.602944    -1.653579 -1.417543
# 2012-01-11        -1.611639         -1.599139    -1.645863 -1.391280
# 2012-01-12        -1.612864         -1.593716    -1.632528 -1.365483
# 2012-01-12        -1.612864         -1.593716    -1.632528 -1.365483
# 2012-01-13        -1.606526         -1.587105    -1.619679 -1.391070
# 2012-01-17        -1.598916         -1.579208    -1.623224 -1.365355
# 2012-01-18        -1.594795         -1.570266    -1.604353 -1.334932
# 2012-01-19        -1.584067         -1.559468    -1.597127 -1.304647
# 2012-01-19        -1.584067         -1.559468    -1.597127 -1.304647
# 2012-01-23        -1.572436         -1.543152    -1.584734 -1.334773
# 2012-01-23        -1.572436         -1.543152    -1.584734 -1.334773
# 2012-01-24        -1.563111         -1.535209    -1.580165 -1.359815
# 2012-01-25        -1.558550         -1.526742    -1.567909 -1.330178
# 2012-01-25        -1.558550         -1.526742    -1.567909 -1.330178
# 2012-01-25        -1.558550         -1.526742    -1.567909 -1.330178
# 2012-01-26        -1.551249         -1.519036    -1.575798 -1.361066
# 2012-01-27        -1.536412         -1.509760    -1.569060 -1.334684
# 2012-01-30        -1.522832         -1.501198    -1.556720 -1.308896
# 2012-01-31        -1.504063         -1.492161    -1.556130 -1.281291
# 2012-02-01        -1.494883         -1.484264    -1.551701 -1.248445
# 2012-02-02        -1.485586         -1.476368    -1.550622 -1.218879
# 2012-02-03        -1.481764         -1.467806    -1.537270 -1.185613
# 2012-02-06        -1.476018         -1.459625    -1.521125 -1.211641
# 2012-02-07        -1.466739         -1.451015    -1.512945 -1.184066
# 2012-02-08        -1.459594         -1.442500    -1.493956 -1.153454
# ...                     ...               ...          ...       ...
# 2017-11-17         2.112738          2.158617     2.066319  2.146076
# 2017-11-20         2.139082          2.170081     2.059565  2.118249
# 2017-11-21         2.164045          2.184304     2.076797  2.147354
# 2017-11-22         2.202978          2.200048     2.084008  2.171894
# 2017-11-24         2.261722          2.217696     2.090661  2.185005
# 2017-11-24         2.261722          2.217696     2.090661  2.185005
# 2017-11-27         2.270781          2.226876     2.090661  2.157603
# 2017-11-28         2.277687          2.236152     2.107029  2.188513
# 2017-11-28         2.277687          2.236152     2.107029  2.188513
# 2017-11-29         2.285845          2.239101     2.094748  2.150612
# 2017-11-30         2.296493          2.244666     2.111198  2.188601
# 2017-12-01         2.311780          2.249518     2.123289  2.153162
# 2017-12-04         2.306245          2.247996     2.102657  2.115667
# 2017-12-05         2.299249          2.245665     2.094155  2.147861
# 2017-12-06         2.296441          2.244333     2.106589  2.177093
# 2017-12-07         2.294981          2.242906     2.110120  2.206979
# 2017-12-08         2.296758          2.244476     2.100861  2.234885
# 2017-12-11         2.297948          2.248519     2.118295  2.262992
# 2017-12-12         2.299656          2.251754     2.113834  2.234227
# 2017-12-13         2.304100          2.256558     2.104318  2.263888
# 2017-12-14         2.316762          2.262837     2.089297  2.233213
# 2017-12-15         2.311195          2.268878     2.117844  2.287455
# 2017-12-18         2.303744          2.278296     2.123717  2.320589
# 2017-12-19         2.306031          2.286478     2.118754  2.288588
# 2017-12-20         2.304214          2.290902     2.115917  2.259623
# 2017-12-26         2.301984          2.298988     2.122062  2.243739
# 2017-12-27         2.301948          2.299559     2.119125  2.265519
# 2017-12-28         2.311179          2.305743     2.117141  2.285781
# 2017-12-28         2.311179          2.305743     2.117141  2.285781
# 2017-12-29         2.313278          2.307170     2.102076  2.261495
#
#                  WMA       MOM     WILLR     SlowK     SlowD  4. close
# date
# 2012-01-03 -1.619615 -0.250682  0.532200  0.120858  0.088106 -1.582821
# 2012-01-04 -1.614984 -0.375885  0.906305  0.480195  0.126935 -1.575272
# 2012-01-05 -1.608648 -0.191763  1.019731  1.213098  0.655096 -1.557346
# 2012-01-06 -1.601807 -0.140209  0.912639  1.291376  1.075262 -1.550741
# 2012-01-09 -1.595576  0.102832  0.801777  1.063765  1.284739 -1.555459
# 2012-01-10 -1.588206 -0.044466  0.790107  0.845734  1.152871 -1.540363
# 2012-01-11 -1.580601  0.191210  0.889299  0.767456  0.964806 -1.535645
# 2012-01-12 -1.572454  0.441616  1.028857  0.988123  0.937655 -1.526210
# 2012-01-12 -1.572454  0.441616  1.028857  0.988123  0.937655 -1.526210
# 2012-01-13 -1.565725  0.625738  0.833886  0.866596  0.945145 -1.535645
# 2012-01-17 -1.557727  0.824590  0.875495  0.772370  0.946908 -1.515831
# 2012-01-18 -1.547497  0.986617  1.067850  0.833978  0.891578 -1.484696
# 2012-01-19 -1.536670  1.273847  1.006999  1.147982  0.992584 -1.469599
# 2012-01-19 -1.536670  1.273847  1.006999  1.147982  0.992584 -1.469599
# 2012-01-23 -1.518672  0.986617  0.768517  0.964319  1.229421 -1.474317
# 2012-01-23 -1.518672  0.986617  0.768517  0.964319  1.229421 -1.474317
# 2012-01-24 -1.511144  0.831955  0.698725  0.567151  1.020926 -1.477147
# 2012-01-25 -1.501478  0.912968  0.986692  0.557588  0.753774 -1.446955
# 2012-01-25 -1.501478  0.912968  0.986692  0.557588  0.753774 -1.446955
# 2012-01-25 -1.501478  0.912968  0.986692  0.557588  0.753774 -1.446955
# 2012-01-26 -1.493611  0.795130  0.692649  0.340620  0.529889 -1.457334
# 2012-01-27 -1.485844  1.038171  0.798357  0.400687  0.470137 -1.450729
# 2012-01-30 -1.478686  0.927698  0.831559  0.212013  0.346092 -1.447899
# 2012-01-31 -1.472071  1.001347  0.794894  0.389136  0.363505 -1.445068
# 2012-02-01 -1.464506  0.824590  0.906305  0.597060  0.433995 -1.426198
# 2012-02-02 -1.456969  0.824590  0.921937  0.772642  0.635242 -1.418650
# 2012-02-03 -1.447200  0.927698  1.014286  1.110387  0.894140 -1.387514
# 2012-02-06 -1.438334  0.868779  0.996428  1.229702  1.121235 -1.388458
# 2012-02-07 -1.429884  0.935063  0.957826  1.256269  1.294838 -1.384684
# 2012-02-08 -1.420987  0.920333  1.067850  1.295874  1.361420 -1.371474
# ...              ...       ...       ...       ...       ...       ...
# 2017-11-17  2.186690  1.119185  0.699756  0.067366 -0.240400  2.184613
# 2017-11-20  2.192763  1.376955  0.640062  0.512351  0.126116  2.178952
# 2017-11-21  2.204074  1.804118  1.058656  0.639475  0.441527  2.244997
# 2017-11-22  2.214666  2.039794  1.020067  0.959510  0.761774  2.251602
# 2017-11-24  2.225840  2.334389  1.043706  1.384414  1.074807  2.273303
# 2017-11-24  2.225840  2.334389  1.043706  1.384414  1.074807  2.273303
# 2017-11-27  2.235068  1.023441  0.856765  1.239429  1.290169  2.270472
# 2017-11-28  2.244959  1.038171  1.023792  1.262313  1.398861  2.286512
# 2017-11-28  2.244959  1.038171  1.023792  1.262313  1.398861  2.286512
# 2017-11-29  2.243847  0.058643 -0.621027  0.273924  1.000241  2.180839
# 2017-11-30  2.247426  0.463711  0.186696 -0.100647  0.519206  2.232732
# 2017-12-01  2.247946  0.353238 -0.439901 -0.686531 -0.180351  2.206313
# 2017-12-04  2.241317 -0.633656 -1.707786 -0.832359 -0.577462  2.136494
# 2017-12-05  2.234923 -0.758859 -1.690651 -1.386083 -1.038882  2.137437
# 2017-12-06  2.231281 -0.604196 -1.210912 -1.531565 -1.342214  2.163856
# 2017-12-07  2.229844 -0.618926 -0.816843 -0.945685 -1.382895  2.185556
# 2017-12-08  2.231163 -0.154939 -0.319968 -0.180734 -0.950223  2.212918
# 2017-12-11  2.236762  0.228035  0.519576  0.593761 -0.187319  2.259150
# 2017-12-12  2.241073  0.102832  0.348241  1.013627  0.515996  2.249715
# 2017-12-13  2.246070  0.345873  0.536708  1.104569  0.977370  2.260094
# 2017-12-14  2.250160  0.574184  0.431766  0.610323  0.983318  2.255376
# 2017-12-15  2.260521  0.537360  0.996279  0.709940  0.874307  2.327083
# 2017-12-18  2.274556  1.060266  0.950464  0.850155  0.782981  2.371428
# 2017-12-19  2.284805  0.868779  0.574829  0.947773  0.904113  2.341235
# 2017-12-20  2.293463  0.286954  0.469182  0.518748  0.835482  2.332744
# 2017-12-26  2.313069 -0.199128  0.011378 -1.045783 -0.547916  2.295947
# 2017-12-27  2.317195 -0.309601  0.034857 -1.431222 -1.081845  2.297834
# 2017-12-28  2.321808  0.559454  0.105288 -1.270281 -1.341240  2.303495
# 2017-12-28  2.321808  0.559454  0.105288 -1.270281 -1.341240  2.303495
# 2017-12-29  2.321768 -0.177033 -0.422946 -1.584300 -1.534546  2.261037
#
# [1652 rows x 21 columns]

# %%
X.to_csv('X.csv')

# %% [markdown]
# # Adding Change features in API data

# %%
X=pd.read_csv('X.csv')

# %%
X =pd.merge(X, change_feature, on='date')

# %%
X
# Out:
#             date       SMA       EMA  MACD_Signal  MACD_Hist      MACD  \
# 0     2012-01-04 -1.611459 -1.609446    -0.673373   0.667406 -0.397989
# 1     2012-01-05 -1.610127 -1.603442    -0.592500   0.841103 -0.260939
# 2     2012-01-06 -1.608462 -1.597376    -0.502048   0.943506 -0.139950
# 3     2012-01-10 -1.602944 -1.586334    -0.322052   0.950853  0.031743
# 4     2012-01-11 -1.599139 -1.580446    -0.232287   0.936150  0.110910
# 5     2012-01-12 -1.593716 -1.574212    -0.143705   0.923519  0.189693
# 6     2012-01-12 -1.593716 -1.574212    -0.143705   0.923519  0.189693
# 7     2012-01-13 -1.587105 -1.569478    -0.066804   0.798662  0.218041
# 8     2012-01-17 -1.579208 -1.563292     0.008517   0.781782  0.282875
# 9     2012-01-18 -1.570266 -1.554701     0.094790   0.898853  0.405095
# 10    2012-01-19 -1.559468 -1.545479     0.190196   0.996420  0.529031
# 11    2012-01-19 -1.559468 -1.545479     0.190196   0.996420  0.529031
# 12    2012-01-30 -1.501198 -1.496053     0.657003   0.423546  0.766185
# 13    2012-01-31 -1.492161 -1.490058     0.689389   0.322846  0.761204
# 14    2012-02-01 -1.484264 -1.482821     0.721697   0.322030  0.791273
# 15    2012-02-02 -1.476368 -1.475547     0.753426   0.315859  0.818914
# 16    2012-02-03 -1.467806 -1.465974     0.797327   0.445921  0.905886
# 17    2012-02-06 -1.459625 -1.457403     0.842827   0.463021  0.954646
# 18    2012-02-07 -1.451015 -1.449286     0.885732   0.435326  0.985222
# 19    2012-02-08 -1.442500 -1.440672     0.928702   0.435976  1.025822
# 20    2012-02-10 -1.425519 -1.424261     1.009443   0.340692  1.068179
# 21    2012-02-13 -1.416148 -1.415945     1.041639   0.320827  1.091443
# 22    2012-02-14 -1.407491 -1.407877     1.070370   0.283776  1.105409
# 23    2012-02-15 -1.401307 -1.402300     1.081637   0.097148  1.050377
# 24    2012-02-16 -1.394172 -1.393990     1.096390   0.134384  1.077329
# 25    2012-02-17 -1.387180 -1.387197     1.104477   0.063134  1.059876
# 26    2012-02-21 -1.379902 -1.380507     1.107204   0.005858  1.042300
# 27    2012-02-22 -1.372957 -1.375361     1.097283  -0.129366  0.985435
# 28    2012-02-23 -1.366821 -1.369345     1.083927  -0.166049  0.959989
# 29    2012-02-24 -1.359734 -1.363085     1.069982  -0.172351  0.944671
# ...          ...       ...       ...          ...        ...       ...
# 1407  2017-11-17  2.158617  2.166480     1.669623  -0.376719  1.436188
# 1408  2017-11-17  2.158617  2.166480     1.669623  -0.376719  1.436188
# 1409  2017-11-20  2.170081  2.171952     1.623200  -0.519500  1.342374
# 1410  2017-11-21  2.184304  2.183251     1.602439  -0.245182  1.419318
# 1411  2017-11-22  2.200048  2.194109     1.597489  -0.076242  1.474066
# 1412  2017-11-24  2.217696  2.206018     1.609732   0.107559  1.550193
# 1413  2017-11-24  2.217696  2.206018     1.609732   0.107559  1.550193
# 1414  2017-11-27  2.226876  2.216521     1.625483   0.145085  1.578185
# 1415  2017-11-28  2.236152  2.227565     1.646435   0.200614  1.617394
# 1416  2017-11-28  2.236152  2.227565     1.646435   0.200614  1.617394
# 1417  2017-11-29  2.239101  2.227401     1.605704  -0.458634  1.347340
# 1418  2017-11-30  2.244666  2.232241     1.552235  -0.594824  1.249217
# 1419  2017-12-01  2.249518  2.234080     1.473984  -0.859689  1.082573
# 1420  2017-12-04  2.247996  2.229034     1.340778  -1.447098  0.750892
# 1421  2017-12-05  2.245665  2.224560     1.176192  -1.782493  0.478336
# 1422  2017-12-06  2.244333  2.223050     1.011178  -1.787084  0.321685
# 1423  2017-12-07  2.242906  2.223770     0.862908  -1.608094  0.245318
# 1424  2017-12-08  2.244476  2.227051     0.744754  -1.286190  0.247490
# 1425  2017-12-11  2.248519  2.234463     0.674272  -0.776667  0.360415
# 1426  2017-12-12  2.251754  2.240262     0.629199  -0.505061  0.413567
# 1427  2017-12-13  2.256558  2.246506     0.605363  -0.278073  0.470981
# 1428  2017-12-14  2.262837  2.251702     0.590702  -0.179997  0.491693
# 1429  2017-12-15  2.268878  2.263294     0.619666   0.286251  0.682833
# 1430  2017-12-18  2.278296  2.278045     0.696284   0.795651  0.933922
# 1431  2017-12-19  2.286478  2.288489     0.779016   0.860985  1.034621
# 1432  2017-12-20  2.290902  2.297122     0.853365   0.771389  1.072972
# 1433  2017-12-27  2.299559  2.317172     0.954762  -0.180708  0.833482
# 1434  2017-12-28  2.305743  2.320263     0.925039  -0.340984  0.749204
# 1435  2017-12-28  2.305743  2.320263     0.925039  -0.340984  0.749204
# 1436  2017-12-29  2.307170  2.318978     0.860401  -0.714203  0.557252
#
#            RSI       ADX       CCI  Aroon Down       ...        4. close  \
# 0    -0.185283 -1.608967  0.793523    0.260194       ...       -1.575272
# 1    -0.002229 -1.588809  1.138424    0.117532       ...       -1.557346
# 2     0.065193 -1.549648  1.315156   -0.025130       ...       -1.550741
# 3     0.162543 -1.446462  1.153570   -0.310454       ...       -1.540363
# 4     0.213824 -1.390863  0.886389   -0.453116       ...       -1.535645
# 5     0.318167 -1.325713  0.778620   -0.595777       ...       -1.526210
# 6     0.318167 -1.325713  0.778620   -0.595777       ...       -1.526210
# 7     0.164829 -1.281491  0.531302   -0.738439       ...       -1.535645
# 8     0.392714 -1.186645  0.784976   -0.881101       ...       -1.515831
# 9     0.724212 -1.061662  0.930042   -1.023763       ...       -1.484696
# 10    0.874909 -0.913427  1.098352   -1.166425       ...       -1.469599
# 11    0.874909 -0.913427  1.098352   -1.166425       ...       -1.469599
# 12    0.963454  0.116318  0.491768   -1.166425       ...       -1.447899
# 13    0.997258  0.237851  0.561798   -1.166425       ...       -1.445068
# 14    1.218703  0.375451  0.719516   -1.023763       ...       -1.426198
# 15    1.304419  0.516272  0.766772   -1.166425       ...       -1.418650
# 16    1.633542  0.687930  1.077500   -1.166425       ...       -1.387514
# 17    1.609978  0.847541  0.951724   -1.023763       ...       -1.388458
# 18    1.649704  1.012441  0.902956   -1.166425       ...       -1.384684
# 19    1.787906  1.179579  0.928728   -0.738439       ...       -1.371474
# 20    1.524460  1.528725  0.723541   -1.023763       ...       -1.370531
# 21    1.744181  1.709136  0.846538   -1.166425       ...       -1.349774
# 22    1.801925  1.882903  0.751537   -1.166425       ...       -1.344113
# 23    1.325796  2.077342  0.659131   -1.166425       ...       -1.362039
# 24    1.692999  2.253875  0.664467   -0.738439       ...       -1.328073
# 25    1.501725  2.421583  0.628230   -0.881101       ...       -1.335621
# 26    1.563391  2.590375  0.622761   -1.023763       ...       -1.329960
# 27    1.315776  2.750728  0.487247   -1.166425       ...       -1.339395
# 28    1.482138  2.903068  0.488928   -0.738439       ...       -1.325242
# 29    1.579266  3.061810  0.667162   -0.881101       ...       -1.316751
# ...        ...       ...       ...         ...       ...             ...
# 1407  0.796053  0.076643  0.359339   -0.738439       ...        2.184613
# 1408  0.796053  0.076643  0.359339   -0.738439       ...        2.184613
# 1409  0.717285  0.089360  0.238806   -0.881101       ...        2.178952
# 1410  1.211014  0.157703  0.698053   -1.023763       ...        2.244997
# 1411  1.256131  0.233090  0.906679   -1.166425       ...        2.251602
# 1412  1.403801  0.323573  1.213551   -1.166425       ...        2.273303
# 1413  1.403801  0.323573  1.213551   -1.166425       ...        2.273303
# 1414  1.360352  0.417991  1.152659   -1.166425       ...        2.270472
# 1415  1.473245  0.494232  1.045495   -0.738439       ...        2.286512
# 1416  1.473245  0.494232  1.045495   -0.738439       ...        2.286512
# 1417  0.043806  0.394340 -0.148435   -0.881101       ...        2.180839
# 1418  0.459783  0.299437  0.090690   -1.023763       ...        2.232732
# 1419  0.159913  0.201512 -0.622846   -1.166425       ...        2.206313
# 1420 -0.548774  0.087678 -0.936840   -0.025130       ...        2.136494
# 1421 -0.540356  0.004707 -1.274507   -0.167792       ...        2.137437
# 1422 -0.303733 -0.071691 -1.240347   -0.310454       ...        2.163856
# 1423 -0.115387 -0.184614 -0.597146   -0.453116       ...        2.185556
# 1424  0.114133 -0.257063  0.021799   -0.595777       ...        2.212918
# 1425  0.473481 -0.306660  0.372506   -0.738439       ...        2.259150
# 1426  0.364709 -0.341716  0.405220   -0.881101       ...        2.249715
# 1427  0.446415 -0.359222  0.514636   -1.023763       ...        2.260094
# 1428  0.388019 -0.367248  0.449831   -1.166425       ...        2.255376
# 1429  0.929218 -0.320260  1.014831    0.688179       ...        2.327083
# 1430  1.215510 -0.223162  1.585379    0.545518       ...        2.371428
# 1431  0.840408 -0.183972  1.055096    0.402856       ...        2.341235
# 1432  0.736486 -0.170728  0.772393    0.260194       ...        2.332744
# 1433  0.271889 -0.323311  0.108567   -0.310454       ...        2.297834
# 1434  0.324265 -0.379509  0.114145   -0.453116       ...        2.303495
# 1435  0.324265 -0.379509  0.114145   -0.453116       ...        2.303495
# 1436 -0.224855 -0.486928 -0.222502   -0.595777       ...        2.261037
#
#       Change_oil  Change_DAX  Change_gold  Change_Nikkei  Change_SP  \
# 0           1.40       -0.89         0.76           1.24       0.02
# 1          -0.84       -0.25         0.47          -0.83       0.29
# 2           0.28       -0.62        -0.20          -1.16      -0.25
# 3           0.74        2.42         1.46           0.38       0.89
# 4          -0.92       -0.17         0.50           0.30       0.03
# 5          -0.87        0.44         0.49          -0.74       0.23
# 6          -0.87        0.44         0.49          -0.74       0.23
# 7          -0.74       -0.58        -1.03           1.36      -0.49
# 8           0.30        1.82         1.52           1.05       0.36
# 9          -0.78        0.34         0.26           0.99       1.11
# 10          0.80        0.97        -0.33           1.04       0.49
# 11          0.80        0.97        -0.33           1.04       0.49
# 12         -0.64       -1.04        -0.05          -0.54      -0.25
# 13          0.21        0.22         0.39           0.11      -0.05
# 14          0.52        2.44         0.54           0.08       0.89
# 15          0.46        0.59         0.56           0.76       0.11
# 16          2.24        1.67        -1.08          -0.51       1.46
# 17          1.18       -0.03        -0.87           1.10      -0.04
# 18          0.26       -0.16         1.37          -0.13       0.20
# 19          0.83       -0.08        -0.98           1.10       0.22
# 20         -1.08       -1.41        -0.90          -0.61      -0.69
# 21          0.53        0.68        -0.02           0.58       0.68
# 22          0.20       -0.15        -0.41           0.59      -0.09
# 23          0.65        0.44         0.61           2.30      -0.54
# 24          0.99       -0.09         0.03          -0.24       1.10
# 25         -0.44        1.42        -0.13           1.58       0.23
# 26          1.34       -0.58         1.89          -0.23       0.07
# 27          1.02       -0.93         0.73           0.96      -0.33
# 28          0.59       -0.50         0.84           0.44       0.43
# 29          1.50        0.81        -0.55           0.54       0.17
# ...          ...         ...          ...            ...        ...
# 1407        2.22       -0.41         1.44           0.20      -0.26
# 1408        2.22       -0.41         1.44           0.20      -0.26
# 1409       -0.80        0.50        -1.64          -0.60       0.13
# 1410        0.56        0.83         0.51           0.70       0.65
# 1411        1.20       -1.16         4.06           0.48      -0.08
# 1412        0.49        0.39         2.48           0.12       0.21
# 1413        0.49        0.39         2.48           0.12       0.21
# 1414       -0.03       -0.46         0.54          -0.24      -0.04
# 1415       -0.36        0.46        -2.71          -0.04       0.98
# 1416       -0.36        0.46        -2.71          -0.04       0.98
# 1417       -0.79        0.02        -0.97           0.49      -0.04
# 1418        0.73       -0.29        -0.69           0.57       0.82
# 1419        0.25       -1.25         3.25           0.41      -0.20
# 1420       -2.01        1.53        -3.07          -0.49      -0.11
# 1421        0.66       -0.08         1.77          -0.37      -0.37
# 1422       -2.61       -0.38        -2.63          -1.97      -0.01
# 1423        1.60        0.36         2.13           1.45       0.29
# 1424        1.93        0.83        -0.38           1.39       0.55
# 1425        2.03       -0.23        -0.10           0.56       0.32
# 1426       -2.09        0.46        -0.78          -0.32       0.15
# 1427       -1.42       -0.44        -2.21          -0.47      -0.05
# 1428        1.39       -0.44         3.88          -0.28      -0.41
# 1429       -0.13        0.27         0.02          -0.62       0.90
# 1430        0.28        1.59         0.63           1.55       0.54
# 1431        0.62       -0.72        -3.18          -0.15      -0.32
# 1432        1.19       -1.11         3.63           0.10      -0.08
# 1433       -0.87       -0.02         0.29           0.08       0.08
# 1434        0.42       -0.69        -2.58          -0.56       0.18
# 1435        0.42       -0.69        -2.58          -0.56       0.18
# 1436        0.22       -0.48         4.12          -0.08      -0.52
#
#       Change_Shanghai  Change_USD_EUR  Change_USD_GBP  Change_USD_JPY
# 0               -1.37            0.82            0.17           -0.02
# 1               -0.97            1.26            0.84            0.58
# 2                0.70            0.50            0.39           -0.27
# 3                2.69           -0.08           -0.17           -0.02
# 4               -0.42            0.55            1.02            0.02
# 5               -0.05           -0.94           -0.11           -0.10
# 6               -0.05           -0.94           -0.11           -0.10
# 7               -1.34            1.21            0.11            0.22
# 8                4.18           -0.57           -0.06           -0.01
# 9               -1.39           -0.96           -0.64           -0.04
# 10               1.31           -0.80           -0.34            0.37
# 11               1.31           -0.80           -0.34            0.37
# 12              -1.47            0.69            0.19           -0.42
# 13               0.33            0.46           -0.33           -0.13
# 14              -1.07           -0.61           -0.49           -0.10
# 15               1.96            0.09            0.17           -0.01
# 16               0.77            0.01           -0.09            0.55
# 17               0.03            0.14           -0.02           -0.05
# 18              -1.68           -1.04           -0.49            0.27
# 19               2.43            0.04            0.54            0.39
# 20               0.10            0.80            0.47           -0.06
# 21              -0.01           -0.09           -0.16           -0.12
# 22              -0.30            0.57            0.52            1.15
# 23               0.94            0.38           -0.06            0.12
# 24              -0.42           -0.51           -0.66            0.42
# 25               0.01           -0.13           -0.22            0.92
# 26               0.75            0.03            0.41            0.30
# 27               0.93           -0.05            0.74            0.52
# 28               0.25           -0.98           -0.50           -0.41
# 29               1.25           -0.62           -0.88            1.57
# ...               ...             ...             ...             ...
# 1407            -0.48           -0.21           -0.15           -0.87
# 1408            -0.48           -0.21           -0.15           -0.87
# 1409             0.28            0.54           -0.16            0.48
# 1410             0.53           -0.06           -0.04           -0.16
# 1411             0.59           -0.72           -0.66           -1.09
# 1412             0.06           -0.66           -0.21            0.30
# 1413             0.06           -0.66           -0.21            0.30
# 1414            -0.94            0.27            0.15           -0.41
# 1415             0.34            0.48           -0.16            0.35
# 1416             0.34            0.48           -0.16            0.35
# 1417             0.13           -0.06           -0.52            0.40
# 1418            -0.62           -0.47           -0.87            0.54
# 1419             0.01            0.11            0.39           -0.37
# 1420            -0.24            0.21           -0.04            0.28
# 1421            -0.18            0.34            0.27            0.15
# 1422            -0.29            0.26            0.38           -0.26
# 1423            -0.67            0.19           -0.62            0.69
# 1424             0.55            0.07            0.63            0.35
# 1425             0.98           -0.04            0.39            0.07
# 1426            -1.25            0.24            0.16           -0.01
# 1427             0.68           -0.72           -0.77           -0.88
# 1428            -0.32            0.40           -0.07           -0.14
# 1429            -0.80            0.21            0.82            0.17
# 1430             0.05           -0.24           -0.47           -0.03
# 1431             0.88           -0.49           -0.01            0.30
# 1432            -0.27           -0.26            0.08            0.44
# 1433            -0.92           -0.26           -0.17            0.11
# 1434             0.63           -0.44           -0.33           -0.41
# 1435             0.63           -0.44           -0.33           -0.41
# 1436             0.33           -0.47           -0.54           -0.18
#
# [1437 rows x 31 columns]

# %%
y.head()
y.to_csv('y.csv')

# %%
y=pd.read_csv('y.csv')

# %%
y=pd.read_csv('y.csv')
y.columns = ['date', 'y']
y.head()
# Out:
#          date  y
# 0  2012-01-04  1
# 1  2012-01-05  1
# 2  2012-01-06  0
# 3  2012-01-09  1
# 4  2012-01-10  1

# %%
X =pd.merge(X, y, on='date')

# %%
X
# Out:
#             date       SMA       EMA  MACD_Signal  MACD_Hist      MACD  \
# 0     2012-01-04 -1.611459 -1.609446    -0.673373   0.667406 -0.397989
# 1     2012-01-05 -1.610127 -1.603442    -0.592500   0.841103 -0.260939
# 2     2012-01-06 -1.608462 -1.597376    -0.502048   0.943506 -0.139950
# 3     2012-01-10 -1.602944 -1.586334    -0.322052   0.950853  0.031743
# 4     2012-01-11 -1.599139 -1.580446    -0.232287   0.936150  0.110910
# 5     2012-01-12 -1.593716 -1.574212    -0.143705   0.923519  0.189693
# 6     2012-01-12 -1.593716 -1.574212    -0.143705   0.923519  0.189693
# 7     2012-01-12 -1.593716 -1.574212    -0.143705   0.923519  0.189693
# 8     2012-01-12 -1.593716 -1.574212    -0.143705   0.923519  0.189693
# 9     2012-01-13 -1.587105 -1.569478    -0.066804   0.798662  0.218041
# 10    2012-01-17 -1.579208 -1.563292     0.008517   0.781782  0.282875
# 11    2012-01-18 -1.570266 -1.554701     0.094790   0.898853  0.405095
# 12    2012-01-19 -1.559468 -1.545479     0.190196   0.996420  0.529031
# 13    2012-01-19 -1.559468 -1.545479     0.190196   0.996420  0.529031
# 14    2012-01-19 -1.559468 -1.545479     0.190196   0.996420  0.529031
# 15    2012-01-19 -1.559468 -1.545479     0.190196   0.996420  0.529031
# 16    2012-01-30 -1.501198 -1.496053     0.657003   0.423546  0.766185
# 17    2012-01-31 -1.492161 -1.490058     0.689389   0.322846  0.761204
# 18    2012-02-01 -1.484264 -1.482821     0.721697   0.322030  0.791273
# 19    2012-02-02 -1.476368 -1.475547     0.753426   0.315859  0.818914
# 20    2012-02-03 -1.467806 -1.465974     0.797327   0.445921  0.905886
# 21    2012-02-06 -1.459625 -1.457403     0.842827   0.463021  0.954646
# 22    2012-02-07 -1.451015 -1.449286     0.885732   0.435326  0.985222
# 23    2012-02-08 -1.442500 -1.440672     0.928702   0.435976  1.025822
# 24    2012-02-10 -1.425519 -1.424261     1.009443   0.340692  1.068179
# 25    2012-02-13 -1.416148 -1.415945     1.041639   0.320827  1.091443
# 26    2012-02-14 -1.407491 -1.407877     1.070370   0.283776  1.105409
# 27    2012-02-15 -1.401307 -1.402300     1.081637   0.097148  1.050377
# 28    2012-02-16 -1.394172 -1.393990     1.096390   0.134384  1.077329
# 29    2012-02-17 -1.387180 -1.387197     1.104477   0.063134  1.059876
# ...          ...       ...       ...          ...        ...       ...
# 2253  2017-11-24  2.217696  2.206018     1.609732   0.107559  1.550193
# 2254  2017-11-24  2.217696  2.206018     1.609732   0.107559  1.550193
# 2255  2017-11-24  2.217696  2.206018     1.609732   0.107559  1.550193
# 2256  2017-11-27  2.226876  2.216521     1.625483   0.145085  1.578185
# 2257  2017-11-28  2.236152  2.227565     1.646435   0.200614  1.617394
# 2258  2017-11-28  2.236152  2.227565     1.646435   0.200614  1.617394
# 2259  2017-11-28  2.236152  2.227565     1.646435   0.200614  1.617394
# 2260  2017-11-28  2.236152  2.227565     1.646435   0.200614  1.617394
# 2261  2017-11-29  2.239101  2.227401     1.605704  -0.458634  1.347340
# 2262  2017-11-30  2.244666  2.232241     1.552235  -0.594824  1.249217
# 2263  2017-12-01  2.249518  2.234080     1.473984  -0.859689  1.082573
# 2264  2017-12-04  2.247996  2.229034     1.340778  -1.447098  0.750892
# 2265  2017-12-05  2.245665  2.224560     1.176192  -1.782493  0.478336
# 2266  2017-12-06  2.244333  2.223050     1.011178  -1.787084  0.321685
# 2267  2017-12-07  2.242906  2.223770     0.862908  -1.608094  0.245318
# 2268  2017-12-08  2.244476  2.227051     0.744754  -1.286190  0.247490
# 2269  2017-12-11  2.248519  2.234463     0.674272  -0.776667  0.360415
# 2270  2017-12-12  2.251754  2.240262     0.629199  -0.505061  0.413567
# 2271  2017-12-13  2.256558  2.246506     0.605363  -0.278073  0.470981
# 2272  2017-12-14  2.262837  2.251702     0.590702  -0.179997  0.491693
# 2273  2017-12-15  2.268878  2.263294     0.619666   0.286251  0.682833
# 2274  2017-12-18  2.278296  2.278045     0.696284   0.795651  0.933922
# 2275  2017-12-19  2.286478  2.288489     0.779016   0.860985  1.034621
# 2276  2017-12-20  2.290902  2.297122     0.853365   0.771389  1.072972
# 2277  2017-12-27  2.299559  2.317172     0.954762  -0.180708  0.833482
# 2278  2017-12-28  2.305743  2.320263     0.925039  -0.340984  0.749204
# 2279  2017-12-28  2.305743  2.320263     0.925039  -0.340984  0.749204
# 2280  2017-12-28  2.305743  2.320263     0.925039  -0.340984  0.749204
# 2281  2017-12-28  2.305743  2.320263     0.925039  -0.340984  0.749204
# 2282  2017-12-29  2.307170  2.318978     0.860401  -0.714203  0.557252
#
#            RSI       ADX       CCI  Aroon Down ...  Change_oil  Change_DAX  \
# 0    -0.185283 -1.608967  0.793523    0.260194 ...        1.40       -0.89
# 1    -0.002229 -1.588809  1.138424    0.117532 ...       -0.84       -0.25
# 2     0.065193 -1.549648  1.315156   -0.025130 ...        0.28       -0.62
# 3     0.162543 -1.446462  1.153570   -0.310454 ...        0.74        2.42
# 4     0.213824 -1.390863  0.886389   -0.453116 ...       -0.92       -0.17
# 5     0.318167 -1.325713  0.778620   -0.595777 ...       -0.87        0.44
# 6     0.318167 -1.325713  0.778620   -0.595777 ...       -0.87        0.44
# 7     0.318167 -1.325713  0.778620   -0.595777 ...       -0.87        0.44
# 8     0.318167 -1.325713  0.778620   -0.595777 ...       -0.87        0.44
# 9     0.164829 -1.281491  0.531302   -0.738439 ...       -0.74       -0.58
# 10    0.392714 -1.186645  0.784976   -0.881101 ...        0.30        1.82
# 11    0.724212 -1.061662  0.930042   -1.023763 ...       -0.78        0.34
# 12    0.874909 -0.913427  1.098352   -1.166425 ...        0.80        0.97
# 13    0.874909 -0.913427  1.098352   -1.166425 ...        0.80        0.97
# 14    0.874909 -0.913427  1.098352   -1.166425 ...        0.80        0.97
# 15    0.874909 -0.913427  1.098352   -1.166425 ...        0.80        0.97
# 16    0.963454  0.116318  0.491768   -1.166425 ...       -0.64       -1.04
# 17    0.997258  0.237851  0.561798   -1.166425 ...        0.21        0.22
# 18    1.218703  0.375451  0.719516   -1.023763 ...        0.52        2.44
# 19    1.304419  0.516272  0.766772   -1.166425 ...        0.46        0.59
# 20    1.633542  0.687930  1.077500   -1.166425 ...        2.24        1.67
# 21    1.609978  0.847541  0.951724   -1.023763 ...        1.18       -0.03
# 22    1.649704  1.012441  0.902956   -1.166425 ...        0.26       -0.16
# 23    1.787906  1.179579  0.928728   -0.738439 ...        0.83       -0.08
# 24    1.524460  1.528725  0.723541   -1.023763 ...       -1.08       -1.41
# 25    1.744181  1.709136  0.846538   -1.166425 ...        0.53        0.68
# 26    1.801925  1.882903  0.751537   -1.166425 ...        0.20       -0.15
# 27    1.325796  2.077342  0.659131   -1.166425 ...        0.65        0.44
# 28    1.692999  2.253875  0.664467   -0.738439 ...        0.99       -0.09
# 29    1.501725  2.421583  0.628230   -0.881101 ...       -0.44        1.42
# ...        ...       ...       ...         ... ...         ...         ...
# 2253  1.403801  0.323573  1.213551   -1.166425 ...        0.49        0.39
# 2254  1.403801  0.323573  1.213551   -1.166425 ...        0.49        0.39
# 2255  1.403801  0.323573  1.213551   -1.166425 ...        0.49        0.39
# 2256  1.360352  0.417991  1.152659   -1.166425 ...       -0.03       -0.46
# 2257  1.473245  0.494232  1.045495   -0.738439 ...       -0.36        0.46
# 2258  1.473245  0.494232  1.045495   -0.738439 ...       -0.36        0.46
# 2259  1.473245  0.494232  1.045495   -0.738439 ...       -0.36        0.46
# 2260  1.473245  0.494232  1.045495   -0.738439 ...       -0.36        0.46
# 2261  0.043806  0.394340 -0.148435   -0.881101 ...       -0.79        0.02
# 2262  0.459783  0.299437  0.090690   -1.023763 ...        0.73       -0.29
# 2263  0.159913  0.201512 -0.622846   -1.166425 ...        0.25       -1.25
# 2264 -0.548774  0.087678 -0.936840   -0.025130 ...       -2.01        1.53
# 2265 -0.540356  0.004707 -1.274507   -0.167792 ...        0.66       -0.08
# 2266 -0.303733 -0.071691 -1.240347   -0.310454 ...       -2.61       -0.38
# 2267 -0.115387 -0.184614 -0.597146   -0.453116 ...        1.60        0.36
# 2268  0.114133 -0.257063  0.021799   -0.595777 ...        1.93        0.83
# 2269  0.473481 -0.306660  0.372506   -0.738439 ...        2.03       -0.23
# 2270  0.364709 -0.341716  0.405220   -0.881101 ...       -2.09        0.46
# 2271  0.446415 -0.359222  0.514636   -1.023763 ...       -1.42       -0.44
# 2272  0.388019 -0.367248  0.449831   -1.166425 ...        1.39       -0.44
# 2273  0.929218 -0.320260  1.014831    0.688179 ...       -0.13        0.27
# 2274  1.215510 -0.223162  1.585379    0.545518 ...        0.28        1.59
# 2275  0.840408 -0.183972  1.055096    0.402856 ...        0.62       -0.72
# 2276  0.736486 -0.170728  0.772393    0.260194 ...        1.19       -1.11
# 2277  0.271889 -0.323311  0.108567   -0.310454 ...       -0.87       -0.02
# 2278  0.324265 -0.379509  0.114145   -0.453116 ...        0.42       -0.69
# 2279  0.324265 -0.379509  0.114145   -0.453116 ...        0.42       -0.69
# 2280  0.324265 -0.379509  0.114145   -0.453116 ...        0.42       -0.69
# 2281  0.324265 -0.379509  0.114145   -0.453116 ...        0.42       -0.69
# 2282 -0.224855 -0.486928 -0.222502   -0.595777 ...        0.22       -0.48
#
#       Change_gold  Change_Nikkei  Change_SP  Change_Shanghai  Change_USD_EUR  \
# 0            0.76           1.24       0.02            -1.37            0.82
# 1            0.47          -0.83       0.29            -0.97            1.26
# 2           -0.20          -1.16      -0.25             0.70            0.50
# 3            1.46           0.38       0.89             2.69           -0.08
# 4            0.50           0.30       0.03            -0.42            0.55
# 5            0.49          -0.74       0.23            -0.05           -0.94
# 6            0.49          -0.74       0.23            -0.05           -0.94
# 7            0.49          -0.74       0.23            -0.05           -0.94
# 8            0.49          -0.74       0.23            -0.05           -0.94
# 9           -1.03           1.36      -0.49            -1.34            1.21
# 10           1.52           1.05       0.36             4.18           -0.57
# 11           0.26           0.99       1.11            -1.39           -0.96
# 12          -0.33           1.04       0.49             1.31           -0.80
# 13          -0.33           1.04       0.49             1.31           -0.80
# 14          -0.33           1.04       0.49             1.31           -0.80
# 15          -0.33           1.04       0.49             1.31           -0.80
# 16          -0.05          -0.54      -0.25            -1.47            0.69
# 17           0.39           0.11      -0.05             0.33            0.46
# 18           0.54           0.08       0.89            -1.07           -0.61
# 19           0.56           0.76       0.11             1.96            0.09
# 20          -1.08          -0.51       1.46             0.77            0.01
# 21          -0.87           1.10      -0.04             0.03            0.14
# 22           1.37          -0.13       0.20            -1.68           -1.04
# 23          -0.98           1.10       0.22             2.43            0.04
# 24          -0.90          -0.61      -0.69             0.10            0.80
# 25          -0.02           0.58       0.68            -0.01           -0.09
# 26          -0.41           0.59      -0.09            -0.30            0.57
# 27           0.61           2.30      -0.54             0.94            0.38
# 28           0.03          -0.24       1.10            -0.42           -0.51
# 29          -0.13           1.58       0.23             0.01           -0.13
# ...           ...            ...        ...              ...             ...
# 2253         2.48           0.12       0.21             0.06           -0.66
# 2254         2.48           0.12       0.21             0.06           -0.66
# 2255         2.48           0.12       0.21             0.06           -0.66
# 2256         0.54          -0.24      -0.04            -0.94            0.27
# 2257        -2.71          -0.04       0.98             0.34            0.48
# 2258        -2.71          -0.04       0.98             0.34            0.48
# 2259        -2.71          -0.04       0.98             0.34            0.48
# 2260        -2.71          -0.04       0.98             0.34            0.48
# 2261        -0.97           0.49      -0.04             0.13           -0.06
# 2262        -0.69           0.57       0.82            -0.62           -0.47
# 2263         3.25           0.41      -0.20             0.01            0.11
# 2264        -3.07          -0.49      -0.11            -0.24            0.21
# 2265         1.77          -0.37      -0.37            -0.18            0.34
# 2266        -2.63          -1.97      -0.01            -0.29            0.26
# 2267         2.13           1.45       0.29            -0.67            0.19
# 2268        -0.38           1.39       0.55             0.55            0.07
# 2269        -0.10           0.56       0.32             0.98           -0.04
# 2270        -0.78          -0.32       0.15            -1.25            0.24
# 2271        -2.21          -0.47      -0.05             0.68           -0.72
# 2272         3.88          -0.28      -0.41            -0.32            0.40
# 2273         0.02          -0.62       0.90            -0.80            0.21
# 2274         0.63           1.55       0.54             0.05           -0.24
# 2275        -3.18          -0.15      -0.32             0.88           -0.49
# 2276         3.63           0.10      -0.08            -0.27           -0.26
# 2277         0.29           0.08       0.08            -0.92           -0.26
# 2278        -2.58          -0.56       0.18             0.63           -0.44
# 2279        -2.58          -0.56       0.18             0.63           -0.44
# 2280        -2.58          -0.56       0.18             0.63           -0.44
# 2281        -2.58          -0.56       0.18             0.63           -0.44
# 2282         4.12          -0.08      -0.52             0.33           -0.47
#
#       Change_USD_GBP  Change_USD_JPY  y
# 0               0.17           -0.02  1
# 1               0.84            0.58  1
# 2               0.39           -0.27  0
# 3              -0.17           -0.02  1
# 4               1.02            0.02  1
# 5              -0.11           -0.10  0
# 6              -0.11           -0.10  0
# 7              -0.11           -0.10  0
# 8              -0.11           -0.10  0
# 9               0.11            0.22  1
# 10             -0.06           -0.01  1
# 11             -0.64           -0.04  1
# 12             -0.34            0.37  0
# 13             -0.34            0.37  0
# 14             -0.34            0.37  0
# 15             -0.34            0.37  0
# 16              0.19           -0.42  1
# 17             -0.33           -0.13  1
# 18             -0.49           -0.10  1
# 19              0.17           -0.01  1
# 20             -0.09            0.55  0
# 21             -0.02           -0.05  1
# 22             -0.49            0.27  1
# 23              0.54            0.39  1
# 24              0.47           -0.06  1
# 25             -0.16           -0.12  1
# 26              0.52            1.15  0
# 27             -0.06            0.12  1
# 28             -0.66            0.42  0
# 29             -0.22            0.92  1
# ...              ...             ... ..
# 2253           -0.21            0.30  0
# 2254           -0.21            0.30  0
# 2255           -0.21            0.30  0
# 2256            0.15           -0.41  1
# 2257           -0.16            0.35  0
# 2258           -0.16            0.35  0
# 2259           -0.16            0.35  0
# 2260           -0.16            0.35  0
# 2261           -0.52            0.40  1
# 2262           -0.87            0.54  0
# 2263            0.39           -0.37  0
# 2264           -0.04            0.28  1
# 2265            0.27            0.15  1
# 2266            0.38           -0.26  1
# 2267           -0.62            0.69  1
# 2268            0.63            0.35  1
# 2269            0.39            0.07  0
# 2270            0.16           -0.01  1
# 2271           -0.77           -0.88  0
# 2272           -0.07           -0.14  1
# 2273            0.82            0.17  1
# 2274           -0.47           -0.03  0
# 2275           -0.01            0.30  0
# 2276            0.08            0.44  1
# 2277           -0.17            0.11  1
# 2278           -0.33           -0.41  0
# 2279           -0.33           -0.41  0
# 2280           -0.33           -0.41  0
# 2281           -0.33           -0.41  0
# 2282           -0.54           -0.18  1
#
# [2283 rows x 32 columns]

# %% [markdown]
# # Dataset analysis

# %%
X [X .isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [date, SMA, EMA, MACD_Signal, MACD_Hist, MACD, RSI, ADX, CCI, Aroon Down, Aroon Up, Real Upper Band, Real Lower Band, Real Middle Band, Chaikin A/D, OBV, WMA, MOM, WILLR, SlowK, SlowD, 4. close, Change_oil, Change_DAX, Change_gold, Change_Nikkei, Change_SP, Change_Shanghai, Change_USD_EUR, Change_USD_GBP, Change_USD_JPY, y]
# Index: []
#
# [0 rows x 32 columns]

# %%
import numpy as np
np.sum(X
       .isnull().any(axis=1))
# Out:
# 0

# %%
X .isnull().any(axis=0)
# Out:
# date                False
# SMA                 False
# EMA                 False
# MACD_Signal         False
# MACD_Hist           False
# MACD                False
# RSI                 False
# ADX                 False
# CCI                 False
# Aroon Down          False
# Aroon Up            False
# Real Upper Band     False
# Real Lower Band     False
# Real Middle Band    False
# Chaikin A/D         False
# OBV                 False
# WMA                 False
# MOM                 False
# WILLR               False
# SlowK               False
# SlowD               False
# 4. close            False
# Change_oil          False
# Change_DAX          False
# Change_gold         False
# Change_Nikkei       False
# Change_SP           False
# Change_Shanghai     False
# Change_USD_EUR      False
# Change_USD_GBP      False
# Change_USD_JPY      False
# y                   False
# dtype: bool

# %%
X .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2283 entries, 0 to 2282
# Data columns (total 32 columns):
# date                2283 non-null object
# SMA                 2283 non-null float64
# EMA                 2283 non-null float64
# MACD_Signal         2283 non-null float64
# MACD_Hist           2283 non-null float64
# MACD                2283 non-null float64
# RSI                 2283 non-null float64
# ADX                 2283 non-null float64
# CCI                 2283 non-null float64
# Aroon Down          2283 non-null float64
# Aroon Up            2283 non-null float64
# Real Upper Band     2283 non-null float64
# Real Lower Band     2283 non-null float64
# Real Middle Band    2283 non-null float64
# Chaikin A/D         2283 non-null float64
# OBV                 2283 non-null float64
# WMA                 2283 non-null float64
# MOM                 2283 non-null float64
# WILLR               2283 non-null float64
# SlowK               2283 non-null float64
# SlowD               2283 non-null float64
# 4. close            2283 non-null float64
# Change_oil          2283 non-null object
# Change_DAX          2283 non-null object
# Change_gold         2283 non-null object
# Change_Nikkei       2283 non-null object
# Change_SP           2283 non-null object
# Change_Shanghai     2283 non-null object
# Change_USD_EUR      2283 non-null object
# Change_USD_GBP      2283 non-null object
# Change_USD_JPY      2283 non-null object
# y                   2283 non-null int64
# dtypes: float64(21), int64(1), object(10)
# memory usage: 588.6+ KB

# %%
class_y=X.y
labels_X=X.drop(columns=['y','date'])

# %% [markdown]
# # SVM Support Vector Machine

# %%
from sklearn.svm import LinearSVC
y=y
X_train, X_test, y_train, y_test = train_test_split(labels_X, class_y, test_size=0.10, shuffle=True, random_state=2000)

svc=SVC(random_state=5)
svc= svc.fit(X_train , y_train)
svc
# Out:
# C:\Users\HP\Anaconda33\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=5,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_pred1 = svc.predict(X_test)
print('Accuracy score= {:.2f}'.format(svc.score(X_test, y_test)))
# Out:
# Accuracy score= 0.74

# %% [markdown]
# # Precision, Recall, F1

# %%
from sklearn.metrics import classification_report, confusion_matrix


print('\n')
print("Precision, Recall, F1")
print('\n')
CR=classification_report(y_test, y_pred1)
print(CR)
print('\n')
# Out:
# Precision, Recall, F1
#
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83       153
#            1       0.70      0.39      0.50        76
#
#    micro avg       0.74      0.74      0.74       229
#    macro avg       0.73      0.65      0.67       229
# weighted avg       0.73      0.74      0.72       229

# %% [markdown]
# # ROC CURVE

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test, y_pred1)

roc_auc = auc(fpr, tpr)


plt.figure()

plt.plot(fpr, tpr, color='darkorange', lw=1, label='ROC curve (area = %0.2f)' % roc_auc)

plt.xlim([0.0, 1.0])

plt.ylim([0.0, 1.05])

plt.xlabel('False Positive Rate')

plt.ylabel('True Positive Rate')

plt.title('ROC CURVE')

plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# # Random Forest

# %%
Ran_For= RandomForestClassifier(n_estimators=1000,max_depth=30, random_state=100,max_leaf_nodes=1000)
Ran_For= Ran_For.fit(X_train , y_train)
Ran_For
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=30, max_features='auto', max_leaf_nodes=1000,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=None,
#             oob_score=False, random_state=100, verbose=0, warm_start=False)

# %%
y_pred2 = Ran_For.predict(X_test)
print('Accuracy score= {:.2f}'.format(Ran_For.score(X_test, y_test)))
# Out:
# Accuracy score= 0.84

# %% [markdown]
# # Precision, Recall, F1

# %%
from sklearn.metrics import classification_report, confusion_matrix


print('\n')
print("Precision, Recall, F1")
print('\n')
CR=classification_report(y_test, y_pred2)
print(CR)
print('\n')
# Out:
# Precision, Recall, F1
#
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88       153
#            1       0.74      0.79      0.76        76
#
#    micro avg       0.84      0.84      0.84       229
#    macro avg       0.82      0.83      0.82       229
# weighted avg       0.84      0.84      0.84       229

# %% [markdown]
# # ROC CURVE

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test, y_pred2)

roc_auc = auc(fpr, tpr)


plt.figure()

plt.plot(fpr, tpr, color='darkorange', lw=1, label='ROC curve (area = %0.2f)' % roc_auc)

plt.xlim([0.0, 1.0])

plt.ylim([0.0, 1.05])

plt.xlabel('False Positive Rate')

plt.ylabel('True Positive Rate')

plt.title('ROC CURVE')

plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# # Comparison of Results

# %%
from prettytable import PrettyTable
x = PrettyTable()
print('\n')
print("Deatiled Performance of the all models")
x.field_names = ["Model", "Accuracy"]

x.add_row(["SVM", 0.74])
x.add_row(["RandomForestClassifier",0.84])
print(x)
print('\n')
# Out:
# Deatiled Performance of the all models
# +------------------------+----------+
# |         Model          | Accuracy |
# +------------------------+----------+
# |          SVM           |   0.74   |
# | RandomForestClassifier |   0.84   |
# +------------------------+----------+

# %%
x = PrettyTable()
print('\n')
print("Best Model.")
x.field_names = ["Model", "Accuracy"]
x.add_row(["RandomForestClassifier",0.84])
print(x)
print('\n')
# Out:
# Best Model.
# +------------------------+----------+
# |         Model          | Accuracy |
# +------------------------+----------+
# | RandomForestClassifier |   0.84   |
# +------------------------+----------+

# %% [markdown]
# # Best Accuracy of Random Forest Algorithm is 84%

# %% [markdown]
# # Now training all data (training&testing) on Random Forest Algorithm

# %%
class_y=X.y
labels_X=X.drop(columns=['y','date'])

# %% [markdown]
# # Random Forest

# %%
Ran_For= RandomForestClassifier(n_estimators=1000,max_depth=30, random_state=100,max_leaf_nodes=1000)
Ran_For= Ran_For.fit(labels_X , class_y)
Ran_For
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=30, max_features='auto', max_leaf_nodes=1000,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=None,
#             oob_score=False, random_state=100, verbose=0, warm_start=False)

# %% [markdown]
# # By Entring the Labels of target 1

# %%
data_for_prediction=pd.read_csv('prediction.csv')

# %%
data_for_prediction
# Out:
#    -1.611458897  -1.609445666  -0.673372637  0.667405683  -0.397989086  \
# 0     -1.611459     -1.609446     -0.673373     0.667406     -0.397989
#
#    -0.185283271  -1.60896729  0.79352331  0.260193853  -2.065534681  ...    \
# 0     -0.185283    -1.608967    0.793523     0.260194     -2.065535  ...
#
#    -1.575272426  1.4  -0.89  0.76  1.24  0.02  -1.37  0.82  0.17  -0.02
# 0     -1.575272  1.4  -0.89  0.76  1.24  0.02  -1.37  0.82  0.17  -0.02
#
# [1 rows x 30 columns]

# %% [markdown]
# # Prediction by using trained model

# %%
aa=Ran_For.predict(data_for_prediction)
if aa==1:
    print("stock prediction is 1")
else:
    print("stock prediction is 0")
# Out:
# stock prediction is 1
